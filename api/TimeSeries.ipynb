# %% [markdown]
# #
#
# # TimeSeries
#
# ``` python
# TimeSeries(self, data)
# ```
#
# Time series data
#
# ## Attributes
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [gtype](#modelskill.TimeSeries.gtype) | Geometry type |
# | [n_points](#modelskill.TimeSeries.n_points) | Number of data points |
# | [name](#modelskill.TimeSeries.name) | Name of time series (value item name) |
# | [plot](#modelskill.TimeSeries.plot) | Plot using the ComparerPlotter |
# | [quantity](#modelskill.TimeSeries.quantity) | Quantity of time series |
# | [time](#modelskill.TimeSeries.time) | Time index |
# | [values](#modelskill.TimeSeries.values) | Values as numpy array |
# | [x](#modelskill.TimeSeries.x) | x-coordinate |
# | [y](#modelskill.TimeSeries.y) | y-coordinate |
#
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [equals](#modelskill.TimeSeries.equals) | Check if two TimeSeries are equal |
# | [sel](#modelskill.TimeSeries.sel) | Select data by label |
# | [to_dataframe](#modelskill.TimeSeries.to_dataframe) | Convert matched data to pandas DataFrame |
# | [trim](#modelskill.TimeSeries.trim) | Trim observation data to a given time interval |
#
# ### equals
#
# ``` python
# TimeSeries.equals(other)
# ```
#
# Check if two TimeSeries are equal
#
# ### sel
#
# ``` python
# TimeSeries.sel(**kwargs)
# ```
#
# Select data by label
#
# ### to_dataframe
#
# ``` python
# TimeSeries.to_dataframe()
# ```
#
# Convert matched data to pandas DataFrame
#
# Include x, y coordinates only if gtype=track
#
# #### Returns
#
# | Name | Type         | Description                |
# |------|--------------|----------------------------|
# |      | pd.DataFrame | data as a pandas DataFrame |
#
# ### trim
#
# ``` python
# TimeSeries.trim(start_time=None, end_time=None, buffer='1s')
# ```
#
# Trim observation data to a given time interval
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |----------|------------|------------------------------------------|---------|
# | start_time | pd.Timestamp | start time | `None` |
# | end_time | pd.Timestamp | end time | `None` |
# | buffer | str | buffer time around start and end time, by default “1s” | `'1s'` |
