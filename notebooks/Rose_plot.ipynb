# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

df = pd.read_csv("../tests/testdata/dual_wave_height_and_direction.csv", index_col=0, parse_dates=True)
df.head()
# Out:
#                      Sign. Wave Height_1  Mean Wave Direction_1  \
# time
# 2017-10-27 00:00:00             1.580310              315.08316
# 2017-10-27 03:00:00             1.810125              317.80347
# 2017-10-27 06:00:00             2.022901              328.15550
# 2017-10-27 09:00:00             2.295846              339.15448
# 2017-10-27 12:00:00             2.203860              342.41605
#
#                      Sign. Wave Height_2  Mean Wave Direction_2
# time
# 2017-10-27 00:00:00             1.579729              315.08316
# 2017-10-27 03:00:00             1.794509              317.80347
# 2017-10-27 06:00:00             1.993366              328.15550
# 2017-10-27 09:00:00             2.248454              339.15448
# 2017-10-27 12:00:00             2.162486              342.41605

# %%
from modelskill.rose import wind_rose

# %%
wind_rose(df);
