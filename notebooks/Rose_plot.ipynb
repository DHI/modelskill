# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mikeio
from modelskill.rose import wind_rose

ds = mikeio.read("../tests/testdata/wave_dir.dfs0")
df = ds[[0,2,1,3]].to_dataframe()
data = df.to_numpy()
wind_rose(data, n_sectors=8);
