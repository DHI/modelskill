# %% [markdown]
# # Metocean multi-model comparison
#
# In this example, two metocean wave models "SW_1" and "SW_2" are compared to three observations: two points and one track.

# %%
import numpy as np
import modelskill as ms

# %% [markdown]
# ## Define observations

# %%
fldr = '../tests/testdata/SW/'
o1 = ms.PointObservation(fldr + 'HKNA_Hm0.dfs0', item=0, x=4.2420, y=52.6887, name="HKNA")
o2 = ms.PointObservation(fldr + "eur_Hm0.dfs0", item=0, x=3.2760, y=51.9990, name="EPL")
o3 = ms.TrackObservation(fldr + "Alti_c2_Dutch.dfs0", item=3, name="c2")

# %% [markdown]
# ## Define models

# %%
mr1 = ms.model_result(fldr + 'HKZN_local_2017_DutchCoast.dfsu', name='SW_1', item=0)
mr2 = ms.model_result(fldr + 'HKZN_local_2017_DutchCoast_v2.dfsu', name='SW_2', item=0)

# %% [markdown]
# ## Get spatial and temporal overview

# %%
ms.plotting.spatial_overview(obs=[o1, o2, o3], mod=[mr1, mr2]);

# %%
ms.plotting.temporal_coverage(obs=[o1, o2, o3], mod=[mr1, mr2]);

# %% [markdown]
# ## Compare

# %%
cc = ms.match(obs=[o1, o2, o3], mod=[mr1, mr2])    # returns a collection of comparisons

# %%
cc["EPL"]   # select a single comparer from the collection like this
# Out:
# <Comparer>
# Quantity: Significant wave height [meter]
# Observation: EPL, n_points=67
#  Model: SW_1, rmse=0.224
#  Model: SW_2, rmse=0.232

# %% [markdown]
# ## Perform analysis
# You can perform simple filtering on specific `observation` or specific `model`. You can refer to observations and models using their _name_ or _index_.
#
# The main analysis methods are:
# * skill()
# * mean_skill()
# * scatter()
# * taylor()

# %%
cc.skill()
# Out:
#                      n      bias      rmse     urmse       mae        cc  \
# model observation
# SW_1  EPL           67 -0.066597  0.223597  0.213449  0.188513  0.969846
#       HKNA         386 -0.194260  0.351964  0.293499  0.251839  0.971194
#       c2           113 -0.001210  0.351797  0.351794  0.294585  0.974335
# SW_2  EPL           67 -0.000199  0.232479  0.232479  0.198294  0.969846
#       HKNA         386 -0.100426  0.293033  0.275287  0.214422  0.971194
#       c2           113  0.081431  0.430268  0.422492  0.357138  0.974335
#
#                          si        r2
# model observation
# SW_1  EPL          0.082522  0.932596
#       HKNA         0.094489  0.905300
#       c2           0.127776  0.899507
# SW_2  EPL          0.089879  0.927134
#       HKNA         0.088626  0.934358
#       c2           0.153454  0.849675

# %%
cc.sel(observation="c2").skill()
# Out:
#       observation    n      bias      rmse     urmse       mae        cc  \
# model
# SW_1           c2  113 -0.001210  0.351797  0.351794  0.294585  0.974335
# SW_2           c2  113  0.081431  0.430268  0.422492  0.357138  0.974335
#
#              si        r2
# model
# SW_1   0.127776  0.899507
# SW_2   0.153454  0.849675

# %%
cc.sel(model=0, observation=[0,"c2"]).mean_skill()
# Out:
#          n      bias     rmse     urmse       mae        cc        si  \
# model
# SW_1   499 -0.097735  0.35188  0.322647  0.273212  0.972764  0.111132
# SW_2   499 -0.009497  0.36165  0.348889  0.285780  0.972764  0.121040
#
#              r2
# model
# SW_1   0.902404
# SW_2   0.892016

# %%
cc.sel(model='SW_1').plot.scatter();

# %%
cc.plot.taylor(normalize_std=True, aggregate_observations=False)

# %% [markdown]
# ### Time series plot (specifically for point comparisons)
# If you select an comparison from the collection which is a PointComparer, you can do a time series plot

# %%
cc['EPL'].plot.timeseries(figsize=(12,4));

# %% [markdown]
# ## Filtering on time
# Use the `start` and `end` arguments to do your analysis on part of the time series

# %%
cc.sel(model="SW_1", end='2017-10-28').skill()
# Out:
#                n      bias      rmse     urmse       mae        cc        si  \
# observation
# EPL           48 -0.100116  0.238728  0.216721  0.203709  0.919574  0.100918
# HKNA         281 -0.097075  0.203241  0.178559  0.164563  0.968106  0.070167
# c2            72 -0.188193  0.313787  0.251089  0.258661  0.478554  0.123019
#
#                    r2
# observation
# EPL          0.812073
# HKNA         0.916126
# c2          -1.420894

# %%
cc.sel(model='SW_2', start='2017-10-28').plot.scatter(cmap='OrRd', figsize=(6,7));

# %% [markdown]
# ## Filtering on area
# You can do you analysis in a specific `area` by providing a bounding box or a closed polygon

# %%
bbox = np.array([0.5,52.5,5,54])
polygon = np.array([[6,51],[0,55],[0,51],[6,51]])

# %%
ax = ms.plotting.spatial_overview(obs=[o1, o2, o3], mod=[mr1, mr2]);
ax.plot([bbox[0],bbox[2],bbox[2],bbox[0],bbox[0]],[bbox[1],bbox[1],bbox[3],bbox[3],bbox[1]]);
ax.plot(polygon[:,0],polygon[:,1]);

# %%
cc.sel(model="SW_1", area=bbox).skill()
# Out:
#                n     bias      rmse     urmse       mae        cc        si  \
# observation
# HKNA         386 -0.19426  0.351964  0.293499  0.251839  0.971194  0.094489
# c2            42 -0.05587  0.388404  0.384365  0.336023  0.952688  0.145724
#
#                    r2
# observation
# HKNA         0.905300
# c2           0.749645

# %%
cc.sel(model="SW_2", area=polygon).plot.scatter(backend='plotly')

# %% [markdown]
# ## Skill object
#
# The skill() and mean_skill() methods return a skill object that can visualize results in various ways. The primary methods of the skill object are:
#
# * style()
# * plot.bar()
# * plot.line()
# * plot.grid()
# * sel()

# %%
s = cc.skill()

# %%
s.style()
# Out:
# <style type="text/css">
# #T_8a7b2_row0_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_8a7b2_row0_col2, #T_8a7b2_row0_col3, #T_8a7b2_row0_col4, #T_8a7b2_row0_col6, #T_8a7b2_row4_col7, #T_8a7b2_row5_col5 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_8a7b2_row0_col5, #T_8a7b2_row3_col5, #T_8a7b2_row5_col2, #T_8a7b2_row5_col3, #T_8a7b2_row5_col4, #T_8a7b2_row5_col6, #T_8a7b2_row5_col7 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_8a7b2_row0_col7 {
#   background-color: #fff5e6;
#   color: #000000;
# }
# #T_8a7b2_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8a7b2_row1_col2 {
#   background-color: #ef6548;
#   color: #f1f1f1;
# }
# #T_8a7b2_row1_col3 {
#   background-color: #fdb881;
#   color: #000000;
# }
# #T_8a7b2_row1_col4 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_8a7b2_row1_col5, #T_8a7b2_row4_col5 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_8a7b2_row1_col6 {
#   background-color: #fee1b9;
#   color: #000000;
# }
# #T_8a7b2_row1_col7 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_8a7b2_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_8a7b2_row2_col2 {
#   background-color: #f06749;
#   color: #f1f1f1;
# }
# #T_8a7b2_row2_col3 {
#   background-color: #e8553c;
#   color: #f1f1f1;
# }
# #T_8a7b2_row2_col4 {
#   background-color: #ee6246;
#   color: #f1f1f1;
# }
# #T_8a7b2_row2_col5 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_8a7b2_row2_col6 {
#   background-color: #ec5f43;
#   color: #f1f1f1;
# }
# #T_8a7b2_row2_col7 {
#   background-color: #fdad77;
#   color: #000000;
# }
# #T_8a7b2_row3_col1 {
#   background-color: #dcdddd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_8a7b2_row3_col2 {
#   background-color: #fff2e0;
#   color: #000000;
# }
# #T_8a7b2_row3_col3 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_8a7b2_row3_col4 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_8a7b2_row3_col6 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_8a7b2_row3_col7 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_8a7b2_row4_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_8a7b2_row4_col2 {
#   background-color: #fdc38c;
#   color: #000000;
# }
# #T_8a7b2_row4_col3 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_8a7b2_row4_col4 {
#   background-color: #fee4bf;
#   color: #000000;
# }
# #T_8a7b2_row4_col6 {
#   background-color: #feedd3;
#   color: #000000;
# }
# #T_8a7b2_row5_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_8a7b2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a7b2_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_8a7b2_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_8a7b2_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_8a7b2_level0_col3" class="col_heading level0 col3" >urmse</th>
#       <th id="T_8a7b2_level0_col4" class="col_heading level0 col4" >mae</th>
#       <th id="T_8a7b2_level0_col5" class="col_heading level0 col5" >cc</th>
#       <th id="T_8a7b2_level0_col6" class="col_heading level0 col6" >si</th>
#       <th id="T_8a7b2_level0_col7" class="col_heading level0 col7" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >observation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a7b2_level0_row0" class="row_heading level0 row0" rowspan="3">SW_1</th>
#       <th id="T_8a7b2_level1_row0" class="row_heading level1 row0" >EPL</th>
#       <td id="T_8a7b2_row0_col0" class="data row0 col0" >67</td>
#       <td id="T_8a7b2_row0_col1" class="data row0 col1" >-0.067</td>
#       <td id="T_8a7b2_row0_col2" class="data row0 col2" >0.224</td>
#       <td id="T_8a7b2_row0_col3" class="data row0 col3" >0.213</td>
#       <td id="T_8a7b2_row0_col4" class="data row0 col4" >0.189</td>
#       <td id="T_8a7b2_row0_col5" class="data row0 col5" >0.970</td>
#       <td id="T_8a7b2_row0_col6" class="data row0 col6" >0.083</td>
#       <td id="T_8a7b2_row0_col7" class="data row0 col7" >0.933</td>
#     </tr>
#     <tr>
#       <th id="T_8a7b2_level1_row1" class="row_heading level1 row1" >HKNA</th>
#       <td id="T_8a7b2_row1_col0" class="data row1 col0" >386</td>
#       <td id="T_8a7b2_row1_col1" class="data row1 col1" >-0.194</td>
#       <td id="T_8a7b2_row1_col2" class="data row1 col2" >0.352</td>
#       <td id="T_8a7b2_row1_col3" class="data row1 col3" >0.293</td>
#       <td id="T_8a7b2_row1_col4" class="data row1 col4" >0.252</td>
#       <td id="T_8a7b2_row1_col5" class="data row1 col5" >0.971</td>
#       <td id="T_8a7b2_row1_col6" class="data row1 col6" >0.094</td>
#       <td id="T_8a7b2_row1_col7" class="data row1 col7" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_8a7b2_level1_row2" class="row_heading level1 row2" >c2</th>
#       <td id="T_8a7b2_row2_col0" class="data row2 col0" >113</td>
#       <td id="T_8a7b2_row2_col1" class="data row2 col1" >-0.001</td>
#       <td id="T_8a7b2_row2_col2" class="data row2 col2" >0.352</td>
#       <td id="T_8a7b2_row2_col3" class="data row2 col3" >0.352</td>
#       <td id="T_8a7b2_row2_col4" class="data row2 col4" >0.295</td>
#       <td id="T_8a7b2_row2_col5" class="data row2 col5" >0.974</td>
#       <td id="T_8a7b2_row2_col6" class="data row2 col6" >0.128</td>
#       <td id="T_8a7b2_row2_col7" class="data row2 col7" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_8a7b2_level0_row3" class="row_heading level0 row3" rowspan="3">SW_2</th>
#       <th id="T_8a7b2_level1_row3" class="row_heading level1 row3" >EPL</th>
#       <td id="T_8a7b2_row3_col0" class="data row3 col0" >67</td>
#       <td id="T_8a7b2_row3_col1" class="data row3 col1" >-0.000</td>
#       <td id="T_8a7b2_row3_col2" class="data row3 col2" >0.232</td>
#       <td id="T_8a7b2_row3_col3" class="data row3 col3" >0.232</td>
#       <td id="T_8a7b2_row3_col4" class="data row3 col4" >0.198</td>
#       <td id="T_8a7b2_row3_col5" class="data row3 col5" >0.970</td>
#       <td id="T_8a7b2_row3_col6" class="data row3 col6" >0.090</td>
#       <td id="T_8a7b2_row3_col7" class="data row3 col7" >0.927</td>
#     </tr>
#     <tr>
#       <th id="T_8a7b2_level1_row4" class="row_heading level1 row4" >HKNA</th>
#       <td id="T_8a7b2_row4_col0" class="data row4 col0" >386</td>
#       <td id="T_8a7b2_row4_col1" class="data row4 col1" >-0.100</td>
#       <td id="T_8a7b2_row4_col2" class="data row4 col2" >0.293</td>
#       <td id="T_8a7b2_row4_col3" class="data row4 col3" >0.275</td>
#       <td id="T_8a7b2_row4_col4" class="data row4 col4" >0.214</td>
#       <td id="T_8a7b2_row4_col5" class="data row4 col5" >0.971</td>
#       <td id="T_8a7b2_row4_col6" class="data row4 col6" >0.089</td>
#       <td id="T_8a7b2_row4_col7" class="data row4 col7" >0.934</td>
#     </tr>
#     <tr>
#       <th id="T_8a7b2_level1_row5" class="row_heading level1 row5" >c2</th>
#       <td id="T_8a7b2_row5_col0" class="data row5 col0" >113</td>
#       <td id="T_8a7b2_row5_col1" class="data row5 col1" >0.081</td>
#       <td id="T_8a7b2_row5_col2" class="data row5 col2" >0.430</td>
#       <td id="T_8a7b2_row5_col3" class="data row5 col3" >0.422</td>
#       <td id="T_8a7b2_row5_col4" class="data row5 col4" >0.357</td>
#       <td id="T_8a7b2_row5_col5" class="data row5 col5" >0.974</td>
#       <td id="T_8a7b2_row5_col6" class="data row5 col6" >0.153</td>
#       <td id="T_8a7b2_row5_col7" class="data row5 col7" >0.850</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.style(columns='rmse')
# Out:
# <style type="text/css">
# #T_5b2ac_row0_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5b2ac_row0_col2, #T_5b2ac_row0_col3, #T_5b2ac_row0_col4, #T_5b2ac_row0_col6, #T_5b2ac_row4_col7, #T_5b2ac_row5_col5 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_5b2ac_row0_col5, #T_5b2ac_row3_col5, #T_5b2ac_row5_col2, #T_5b2ac_row5_col3, #T_5b2ac_row5_col4, #T_5b2ac_row5_col6, #T_5b2ac_row5_col7 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_5b2ac_row0_col7 {
#   background-color: #fff5e6;
#   color: #000000;
# }
# #T_5b2ac_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5b2ac_row1_col2 {
#   background-color: #ef6548;
#   color: #f1f1f1;
# }
# #T_5b2ac_row1_col3 {
#   background-color: #fdb881;
#   color: #000000;
# }
# #T_5b2ac_row1_col4 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_5b2ac_row1_col5, #T_5b2ac_row4_col5 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_5b2ac_row1_col6 {
#   background-color: #fee1b9;
#   color: #000000;
# }
# #T_5b2ac_row1_col7 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_5b2ac_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_5b2ac_row2_col2 {
#   background-color: #f06749;
#   color: #f1f1f1;
# }
# #T_5b2ac_row2_col3 {
#   background-color: #e8553c;
#   color: #f1f1f1;
# }
# #T_5b2ac_row2_col4 {
#   background-color: #ee6246;
#   color: #f1f1f1;
# }
# #T_5b2ac_row2_col5 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_5b2ac_row2_col6 {
#   background-color: #ec5f43;
#   color: #f1f1f1;
# }
# #T_5b2ac_row2_col7 {
#   background-color: #fdad77;
#   color: #000000;
# }
# #T_5b2ac_row3_col1 {
#   background-color: #dcdddd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_5b2ac_row3_col2 {
#   background-color: #fff2e0;
#   color: #000000;
# }
# #T_5b2ac_row3_col3 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_5b2ac_row3_col4 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_5b2ac_row3_col6 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_5b2ac_row3_col7 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_5b2ac_row4_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_5b2ac_row4_col2 {
#   background-color: #fdc38c;
#   color: #000000;
# }
# #T_5b2ac_row4_col3 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_5b2ac_row4_col4 {
#   background-color: #fee4bf;
#   color: #000000;
# }
# #T_5b2ac_row4_col6 {
#   background-color: #feedd3;
#   color: #000000;
# }
# #T_5b2ac_row5_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_5b2ac">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b2ac_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_5b2ac_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_5b2ac_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_5b2ac_level0_col3" class="col_heading level0 col3" >urmse</th>
#       <th id="T_5b2ac_level0_col4" class="col_heading level0 col4" >mae</th>
#       <th id="T_5b2ac_level0_col5" class="col_heading level0 col5" >cc</th>
#       <th id="T_5b2ac_level0_col6" class="col_heading level0 col6" >si</th>
#       <th id="T_5b2ac_level0_col7" class="col_heading level0 col7" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >observation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b2ac_level0_row0" class="row_heading level0 row0" rowspan="3">SW_1</th>
#       <th id="T_5b2ac_level1_row0" class="row_heading level1 row0" >EPL</th>
#       <td id="T_5b2ac_row0_col0" class="data row0 col0" >67</td>
#       <td id="T_5b2ac_row0_col1" class="data row0 col1" >-0.067</td>
#       <td id="T_5b2ac_row0_col2" class="data row0 col2" >0.224</td>
#       <td id="T_5b2ac_row0_col3" class="data row0 col3" >0.213</td>
#       <td id="T_5b2ac_row0_col4" class="data row0 col4" >0.189</td>
#       <td id="T_5b2ac_row0_col5" class="data row0 col5" >0.970</td>
#       <td id="T_5b2ac_row0_col6" class="data row0 col6" >0.083</td>
#       <td id="T_5b2ac_row0_col7" class="data row0 col7" >0.933</td>
#     </tr>
#     <tr>
#       <th id="T_5b2ac_level1_row1" class="row_heading level1 row1" >HKNA</th>
#       <td id="T_5b2ac_row1_col0" class="data row1 col0" >386</td>
#       <td id="T_5b2ac_row1_col1" class="data row1 col1" >-0.194</td>
#       <td id="T_5b2ac_row1_col2" class="data row1 col2" >0.352</td>
#       <td id="T_5b2ac_row1_col3" class="data row1 col3" >0.293</td>
#       <td id="T_5b2ac_row1_col4" class="data row1 col4" >0.252</td>
#       <td id="T_5b2ac_row1_col5" class="data row1 col5" >0.971</td>
#       <td id="T_5b2ac_row1_col6" class="data row1 col6" >0.094</td>
#       <td id="T_5b2ac_row1_col7" class="data row1 col7" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_5b2ac_level1_row2" class="row_heading level1 row2" >c2</th>
#       <td id="T_5b2ac_row2_col0" class="data row2 col0" >113</td>
#       <td id="T_5b2ac_row2_col1" class="data row2 col1" >-0.001</td>
#       <td id="T_5b2ac_row2_col2" class="data row2 col2" >0.352</td>
#       <td id="T_5b2ac_row2_col3" class="data row2 col3" >0.352</td>
#       <td id="T_5b2ac_row2_col4" class="data row2 col4" >0.295</td>
#       <td id="T_5b2ac_row2_col5" class="data row2 col5" >0.974</td>
#       <td id="T_5b2ac_row2_col6" class="data row2 col6" >0.128</td>
#       <td id="T_5b2ac_row2_col7" class="data row2 col7" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_5b2ac_level0_row3" class="row_heading level0 row3" rowspan="3">SW_2</th>
#       <th id="T_5b2ac_level1_row3" class="row_heading level1 row3" >EPL</th>
#       <td id="T_5b2ac_row3_col0" class="data row3 col0" >67</td>
#       <td id="T_5b2ac_row3_col1" class="data row3 col1" >-0.000</td>
#       <td id="T_5b2ac_row3_col2" class="data row3 col2" >0.232</td>
#       <td id="T_5b2ac_row3_col3" class="data row3 col3" >0.232</td>
#       <td id="T_5b2ac_row3_col4" class="data row3 col4" >0.198</td>
#       <td id="T_5b2ac_row3_col5" class="data row3 col5" >0.970</td>
#       <td id="T_5b2ac_row3_col6" class="data row3 col6" >0.090</td>
#       <td id="T_5b2ac_row3_col7" class="data row3 col7" >0.927</td>
#     </tr>
#     <tr>
#       <th id="T_5b2ac_level1_row4" class="row_heading level1 row4" >HKNA</th>
#       <td id="T_5b2ac_row4_col0" class="data row4 col0" >386</td>
#       <td id="T_5b2ac_row4_col1" class="data row4 col1" >-0.100</td>
#       <td id="T_5b2ac_row4_col2" class="data row4 col2" >0.293</td>
#       <td id="T_5b2ac_row4_col3" class="data row4 col3" >0.275</td>
#       <td id="T_5b2ac_row4_col4" class="data row4 col4" >0.214</td>
#       <td id="T_5b2ac_row4_col5" class="data row4 col5" >0.971</td>
#       <td id="T_5b2ac_row4_col6" class="data row4 col6" >0.089</td>
#       <td id="T_5b2ac_row4_col7" class="data row4 col7" >0.934</td>
#     </tr>
#     <tr>
#       <th id="T_5b2ac_level1_row5" class="row_heading level1 row5" >c2</th>
#       <td id="T_5b2ac_row5_col0" class="data row5 col0" >113</td>
#       <td id="T_5b2ac_row5_col1" class="data row5 col1" >0.081</td>
#       <td id="T_5b2ac_row5_col2" class="data row5 col2" >0.430</td>
#       <td id="T_5b2ac_row5_col3" class="data row5 col3" >0.422</td>
#       <td id="T_5b2ac_row5_col4" class="data row5 col4" >0.357</td>
#       <td id="T_5b2ac_row5_col5" class="data row5 col5" >0.974</td>
#       <td id="T_5b2ac_row5_col6" class="data row5 col6" >0.153</td>
#       <td id="T_5b2ac_row5_col7" class="data row5 col7" >0.850</td>
#     </tr>
#   </tbody>
# </table>

# %%
s["rmse"].plot.bar();

# %%
s = cc.skill(by=['model','freq:12H'], metrics=['bias','rmse','si'])

# %%
s.style()
# Out:
# <style type="text/css">
# #T_5a705_row0_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_5a705_row0_col2 {
#   background-color: #fdd6a2;
#   color: #000000;
# }
# #T_5a705_row0_col3, #T_5a705_row4_col2 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_5a705_row1_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5a705_row1_col2 {
#   background-color: #fdd7a4;
#   color: #000000;
# }
# #T_5a705_row1_col3 {
#   background-color: #ef6447;
#   color: #f1f1f1;
# }
# #T_5a705_row2_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_5a705_row2_col2 {
#   background-color: #feefda;
#   color: #000000;
# }
# #T_5a705_row2_col3 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_5a705_row3_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5a705_row3_col2 {
#   background-color: #fee9ca;
#   color: #000000;
# }
# #T_5a705_row3_col3 {
#   background-color: #fff3e2;
#   color: #000000;
# }
# #T_5a705_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5a705_row4_col3 {
#   background-color: #f98254;
#   color: #f1f1f1;
# }
# #T_5a705_row5_col1 {
#   background-color: #dedcdb;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_5a705_row5_col2 {
#   background-color: #f16c4b;
#   color: #f1f1f1;
# }
# #T_5a705_row5_col3 {
#   background-color: #c0110b;
#   color: #f1f1f1;
# }
# #T_5a705_row6_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_5a705_row6_col2 {
#   background-color: #fdddb1;
#   color: #000000;
# }
# #T_5a705_row6_col3 {
#   background-color: #a90000;
#   color: #f1f1f1;
# }
# #T_5a705_row7_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_5a705_row7_col2 {
#   background-color: #fdd9aa;
#   color: #000000;
# }
# #T_5a705_row7_col3 {
#   background-color: #e24831;
#   color: #f1f1f1;
# }
# #T_5a705_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_5a705_row8_col2, #T_5a705_row8_col3 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_5a705_row9_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_5a705_row9_col2 {
#   background-color: #fddeb3;
#   color: #000000;
# }
# #T_5a705_row9_col3 {
#   background-color: #feeace;
#   color: #000000;
# }
# #T_5a705_row10_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5a705_row10_col2 {
#   background-color: #da3724;
#   color: #f1f1f1;
# }
# #T_5a705_row10_col3 {
#   background-color: #f98455;
#   color: #f1f1f1;
# }
# #T_5a705_row11_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_5a705_row11_col2 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
# }
# #T_5a705_row11_col3 {
#   background-color: #a10000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a705">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a705_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_5a705_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_5a705_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_5a705_level0_col3" class="col_heading level0 col3" >si</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a705_level0_row0" class="row_heading level0 row0" rowspan="6">SW_1</th>
#       <th id="T_5a705_level1_row0" class="row_heading level1 row0" >2017-10-27 00:00:00</th>
#       <td id="T_5a705_row0_col0" class="data row0 col0" >84</td>
#       <td id="T_5a705_row0_col1" class="data row0 col1" >-0.096</td>
#       <td id="T_5a705_row0_col2" class="data row0 col2" >0.257</td>
#       <td id="T_5a705_row0_col3" class="data row0 col3" >0.117</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row1" class="row_heading level1 row1" >2017-10-27 12:00:00</th>
#       <td id="T_5a705_row1_col0" class="data row1 col0" >156</td>
#       <td id="T_5a705_row1_col1" class="data row1 col1" >-0.166</td>
#       <td id="T_5a705_row1_col2" class="data row1 col2" >0.253</td>
#       <td id="T_5a705_row1_col3" class="data row1 col3" >0.094</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row2" class="row_heading level1 row2" >2017-10-28 00:00:00</th>
#       <td id="T_5a705_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_5a705_row2_col1" class="data row2 col1" >-0.111</td>
#       <td id="T_5a705_row2_col2" class="data row2 col2" >0.178</td>
#       <td id="T_5a705_row2_col3" class="data row2 col3" >0.056</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row3" class="row_heading level1 row3" >2017-10-28 12:00:00</th>
#       <td id="T_5a705_row3_col0" class="data row3 col0" >84</td>
#       <td id="T_5a705_row3_col1" class="data row3 col1" >-0.037</td>
#       <td id="T_5a705_row3_col2" class="data row3 col2" >0.204</td>
#       <td id="T_5a705_row3_col3" class="data row3 col3" >0.058</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row4" class="row_heading level1 row4" >2017-10-29 00:00:00</th>
#       <td id="T_5a705_row4_col0" class="data row4 col0" >82</td>
#       <td id="T_5a705_row4_col1" class="data row4 col1" >-0.421</td>
#       <td id="T_5a705_row4_col2" class="data row4 col2" >0.596</td>
#       <td id="T_5a705_row4_col3" class="data row4 col3" >0.089</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row5" class="row_heading level1 row5" >2017-10-29 12:00:00</th>
#       <td id="T_5a705_row5_col0" class="data row5 col0" >83</td>
#       <td id="T_5a705_row5_col1" class="data row5 col1" >0.007</td>
#       <td id="T_5a705_row5_col2" class="data row5 col2" >0.419</td>
#       <td id="T_5a705_row5_col3" class="data row5 col3" >0.106</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level0_row6" class="row_heading level0 row6" rowspan="6">SW_2</th>
#       <th id="T_5a705_level1_row6" class="row_heading level1 row6" >2017-10-27 00:00:00</th>
#       <td id="T_5a705_row6_col0" class="data row6 col0" >84</td>
#       <td id="T_5a705_row6_col1" class="data row6 col1" >-0.070</td>
#       <td id="T_5a705_row6_col2" class="data row6 col2" >0.236</td>
#       <td id="T_5a705_row6_col3" class="data row6 col3" >0.110</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row7" class="row_heading level1 row7" >2017-10-27 12:00:00</th>
#       <td id="T_5a705_row7_col0" class="data row7 col0" >156</td>
#       <td id="T_5a705_row7_col1" class="data row7 col1" >-0.146</td>
#       <td id="T_5a705_row7_col2" class="data row7 col2" >0.247</td>
#       <td id="T_5a705_row7_col3" class="data row7 col3" >0.098</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row8" class="row_heading level1 row8" >2017-10-28 00:00:00</th>
#       <td id="T_5a705_row8_col0" class="data row8 col0" >77</td>
#       <td id="T_5a705_row8_col1" class="data row8 col1" >-0.056</td>
#       <td id="T_5a705_row8_col2" class="data row8 col2" >0.150</td>
#       <td id="T_5a705_row8_col3" class="data row8 col3" >0.056</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row9" class="row_heading level1 row9" >2017-10-28 12:00:00</th>
#       <td id="T_5a705_row9_col0" class="data row9 col0" >84</td>
#       <td id="T_5a705_row9_col1" class="data row9 col1" >0.091</td>
#       <td id="T_5a705_row9_col2" class="data row9 col2" >0.234</td>
#       <td id="T_5a705_row9_col3" class="data row9 col3" >0.063</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row10" class="row_heading level1 row10" >2017-10-29 00:00:00</th>
#       <td id="T_5a705_row10_col0" class="data row10 col0" >82</td>
#       <td id="T_5a705_row10_col1" class="data row10 col1" >-0.226</td>
#       <td id="T_5a705_row10_col2" class="data row10 col2" >0.477</td>
#       <td id="T_5a705_row10_col3" class="data row10 col3" >0.088</td>
#     </tr>
#     <tr>
#       <th id="T_5a705_level1_row11" class="row_heading level1 row11" >2017-10-29 12:00:00</th>
#       <td id="T_5a705_row11_col0" class="data row11 col0" >83</td>
#       <td id="T_5a705_row11_col1" class="data row11 col1" >0.173</td>
#       <td id="T_5a705_r

# %%
s["rmse"].plot.line(title='Hm0 rmse [m]');

# %%
s["si"].plot.grid(fmt='0.1%', title='Hm0 Scatter index');

# %% [markdown]
# ### The sel() method can subset the skill object
#
# A new skill object will be returned

# %%
s = cc.skill()
s.style()
# Out:
# <style type="text/css">
# #T_38447_row0_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_38447_row0_col2, #T_38447_row0_col3, #T_38447_row0_col4, #T_38447_row0_col6, #T_38447_row4_col7, #T_38447_row5_col5 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_38447_row0_col5, #T_38447_row3_col5, #T_38447_row5_col2, #T_38447_row5_col3, #T_38447_row5_col4, #T_38447_row5_col6, #T_38447_row5_col7 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_38447_row0_col7 {
#   background-color: #fff5e6;
#   color: #000000;
# }
# #T_38447_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_38447_row1_col2 {
#   background-color: #ef6548;
#   color: #f1f1f1;
# }
# #T_38447_row1_col3 {
#   background-color: #fdb881;
#   color: #000000;
# }
# #T_38447_row1_col4 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_38447_row1_col5, #T_38447_row4_col5 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_38447_row1_col6 {
#   background-color: #fee1b9;
#   color: #000000;
# }
# #T_38447_row1_col7 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_38447_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_38447_row2_col2 {
#   background-color: #f06749;
#   color: #f1f1f1;
# }
# #T_38447_row2_col3 {
#   background-color: #e8553c;
#   color: #f1f1f1;
# }
# #T_38447_row2_col4 {
#   background-color: #ee6246;
#   color: #f1f1f1;
# }
# #T_38447_row2_col5 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_38447_row2_col6 {
#   background-color: #ec5f43;
#   color: #f1f1f1;
# }
# #T_38447_row2_col7 {
#   background-color: #fdad77;
#   color: #000000;
# }
# #T_38447_row3_col1 {
#   background-color: #dcdddd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_38447_row3_col2 {
#   background-color: #fff2e0;
#   color: #000000;
# }
# #T_38447_row3_col3 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_38447_row3_col4 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_38447_row3_col6 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_38447_row3_col7 {
#   background-color: #feedd4;
#   color: #000000;
# }
# #T_38447_row4_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_38447_row4_col2 {
#   background-color: #fdc38c;
#   color: #000000;
# }
# #T_38447_row4_col3 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_38447_row4_col4 {
#   background-color: #fee4bf;
#   color: #000000;
# }
# #T_38447_row4_col6 {
#   background-color: #feedd3;
#   color: #000000;
# }
# #T_38447_row5_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_38447">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38447_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_38447_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_38447_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_38447_level0_col3" class="col_heading level0 col3" >urmse</th>
#       <th id="T_38447_level0_col4" class="col_heading level0 col4" >mae</th>
#       <th id="T_38447_level0_col5" class="col_heading level0 col5" >cc</th>
#       <th id="T_38447_level0_col6" class="col_heading level0 col6" >si</th>
#       <th id="T_38447_level0_col7" class="col_heading level0 col7" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >observation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38447_level0_row0" class="row_heading level0 row0" rowspan="3">SW_1</th>
#       <th id="T_38447_level1_row0" class="row_heading level1 row0" >EPL</th>
#       <td id="T_38447_row0_col0" class="data row0 col0" >67</td>
#       <td id="T_38447_row0_col1" class="data row0 col1" >-0.067</td>
#       <td id="T_38447_row0_col2" class="data row0 col2" >0.224</td>
#       <td id="T_38447_row0_col3" class="data row0 col3" >0.213</td>
#       <td id="T_38447_row0_col4" class="data row0 col4" >0.189</td>
#       <td id="T_38447_row0_col5" class="data row0 col5" >0.970</td>
#       <td id="T_38447_row0_col6" class="data row0 col6" >0.083</td>
#       <td id="T_38447_row0_col7" class="data row0 col7" >0.933</td>
#     </tr>
#     <tr>
#       <th id="T_38447_level1_row1" class="row_heading level1 row1" >HKNA</th>
#       <td id="T_38447_row1_col0" class="data row1 col0" >386</td>
#       <td id="T_38447_row1_col1" class="data row1 col1" >-0.194</td>
#       <td id="T_38447_row1_col2" class="data row1 col2" >0.352</td>
#       <td id="T_38447_row1_col3" class="data row1 col3" >0.293</td>
#       <td id="T_38447_row1_col4" class="data row1 col4" >0.252</td>
#       <td id="T_38447_row1_col5" class="data row1 col5" >0.971</td>
#       <td id="T_38447_row1_col6" class="data row1 col6" >0.094</td>
#       <td id="T_38447_row1_col7" class="data row1 col7" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_38447_level1_row2" class="row_heading level1 row2" >c2</th>
#       <td id="T_38447_row2_col0" class="data row2 col0" >113</td>
#       <td id="T_38447_row2_col1" class="data row2 col1" >-0.001</td>
#       <td id="T_38447_row2_col2" class="data row2 col2" >0.352</td>
#       <td id="T_38447_row2_col3" class="data row2 col3" >0.352</td>
#       <td id="T_38447_row2_col4" class="data row2 col4" >0.295</td>
#       <td id="T_38447_row2_col5" class="data row2 col5" >0.974</td>
#       <td id="T_38447_row2_col6" class="data row2 col6" >0.128</td>
#       <td id="T_38447_row2_col7" class="data row2 col7" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_38447_level0_row3" class="row_heading level0 row3" rowspan="3">SW_2</th>
#       <th id="T_38447_level1_row3" class="row_heading level1 row3" >EPL</th>
#       <td id="T_38447_row3_col0" class="data row3 col0" >67</td>
#       <td id="T_38447_row3_col1" class="data row3 col1" >-0.000</td>
#       <td id="T_38447_row3_col2" class="data row3 col2" >0.232</td>
#       <td id="T_38447_row3_col3" class="data row3 col3" >0.232</td>
#       <td id="T_38447_row3_col4" class="data row3 col4" >0.198</td>
#       <td id="T_38447_row3_col5" class="data row3 col5" >0.970</td>
#       <td id="T_38447_row3_col6" class="data row3 col6" >0.090</td>
#       <td id="T_38447_row3_col7" class="data row3 col7" >0.927</td>
#     </tr>
#     <tr>
#       <th id="T_38447_level1_row4" class="row_heading level1 row4" >HKNA</th>
#       <td id="T_38447_row4_col0" class="data row4 col0" >386</td>
#       <td id="T_38447_row4_col1" class="data row4 col1" >-0.100</td>
#       <td id="T_38447_row4_col2" class="data row4 col2" >0.293</td>
#       <td id="T_38447_row4_col3" class="data row4 col3" >0.275</td>
#       <td id="T_38447_row4_col4" class="data row4 col4" >0.214</td>
#       <td id="T_38447_row4_col5" class="data row4 col5" >0.971</td>
#       <td id="T_38447_row4_col6" class="data row4 col6" >0.089</td>
#       <td id="T_38447_row4_col7" class="data row4 col7" >0.934</td>
#     </tr>
#     <tr>
#       <th id="T_38447_level1_row5" class="row_heading level1 row5" >c2</th>
#       <td id="T_38447_row5_col0" class="data row5 col0" >113</td>
#       <td id="T_38447_row5_col1" class="data row5 col1" >0.081</td>
#       <td id="T_38447_row5_col2" class="data row5 col2" >0.430</td>
#       <td id="T_38447_row5_col3" class="data row5 col3" >0.422</td>
#       <td id="T_38447_row5_col4" class="data row5 col4" >0.357</td>
#       <td id="T_38447_row5_col5" class="data row5 col5" >0.974</td>
#       <td id="T_38447_row5_col6" class="data row5 col6" >0.153</td>
#       <td id="T_38447_row5_col7" class="data row5 col7" >0.850</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.sel(model='SW_1').style()
# Out:
# <style type="text/css">
# #T_6e617_row0_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6e617_row0_col3, #T_6e617_row0_col4, #T_6e617_row0_col5, #T_6e617_row0_col7, #T_6e617_row0_col8, #T_6e617_row2_col6 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_6e617_row0_col6, #T_6e617_row1_col3, #T_6e617_row2_col3, #T_6e617_row2_col4, #T_6e617_row2_col5, #T_6e617_row2_col7, #T_6e617_row2_col8 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_6e617_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6e617_row1_col4 {
#   background-color: #f4734e;
#   color: #f1f1f1;
# }
# #T_6e617_row1_col5 {
#   background-color: #f26e4c;
#   color: #f1f1f1;
# }
# #T_6e617_row1_col6 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_6e617_row1_col7 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_6e617_row1_col8 {
#   background-color: #c1120c;
#   color: #f1f1f1;
# }
# #T_6e617_row2_col2 {
#   background-color: #dcdddd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# </style>
# <table id="T_6e617">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e617_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_6e617_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_6e617_level0_col2" class="col_heading level0 col2" >bias</th>
#       <th id="T_6e617_level0_col3" class="col_heading level0 col3" >rmse</th>
#       <th id="T_6e617_level0_col4" class="col_heading level0 col4" >urmse</th>
#       <th id="T_6e617_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_6e617_level0_col6" class="col_heading level0 col6" >cc</th>
#       <th id="T_6e617_level0_col7" class="col_heading level0 col7" >si</th>
#       <th id="T_6e617_level0_col8" class="col_heading level0 col8" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e617_level0_row0" class="row_heading level0 row0" >EPL</th>
#       <td id="T_6e617_row0_col0" class="data row0 col0" >SW_1</td>
#       <td id="T_6e617_row0_col1" class="data row0 col1" >67</td>
#       <td id="T_6e617_row0_col2" class="data row0 col2" >-0.067</td>
#       <td id="T_6e617_row0_col3" class="data row0 col3" >0.224</td>
#       <td id="T_6e617_row0_col4" class="data row0 col4" >0.213</td>
#       <td id="T_6e617_row0_col5" class="data row0 col5" >0.189</td>
#       <td id="T_6e617_row0_col6" class="data row0 col6" >0.970</td>
#       <td id="T_6e617_row0_col7" class="data row0 col7" >0.083</td>
#       <td id="T_6e617_row0_col8" class="data row0 col8" >0.933</td>
#     </tr>
#     <tr>
#       <th id="T_6e617_level0_row1" class="row_heading level0 row1" >HKNA</th>
#       <td id="T_6e617_row1_col0" class="data row1 col0" >SW_1</td>
#       <td id="T_6e617_row1_col1" class="data row1 col1" >386</td>
#       <td id="T_6e617_row1_col2" class="data row1 col2" >-0.194</td>
#       <td id="T_6e617_row1_col3" class="data row1 col3" >0.352</td>
#       <td id="T_6e617_row1_col4" class="data row1 col4" >0.293</td>
#       <td id="T_6e617_row1_col5" class="data row1 col5" >0.252</td>
#       <td id="T_6e617_row1_col6" class="data row1 col6" >0.971</td>
#       <td id="T_6e617_row1_col7" class="data row1 col7" >0.094</td>
#       <td id="T_6e617_row1_col8" class="data row1 col8" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_6e617_level0_row2" class="row_heading level0 row2" >c2</th>
#       <td id="T_6e617_row2_col0" class="data row2 col0" >SW_1</td>
#       <td id="T_6e617_row2_col1" class="data row2 col1" >113</td>
#       <td id="T_6e617_row2_col2" class="data row2 col2" >-0.001</td>
#       <td id="T_6e617_row2_col3" class="data row2 col3" >0.352</td>
#       <td id="T_6e617_row2_col4" class="data row2 col4" >0.352</td>
#       <td id="T_6e617_row2_col5" class="data row2 col5" >0.295</td>
#       <td id="T_6e617_row2_col6" class="data row2 col6" >0.974</td>
#       <td id="T_6e617_row2_col7" class="data row2 col7" >0.128</td>
#       <td id="T_6e617_row2_col8" class="data row2 col8" >0.900</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.sel(observation='HKNA').style()
# Out:
# <style type="text/css">
# #T_e98e2_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e98e2_row0_col3, #T_e98e2_row0_col4, #T_e98e2_row0_col5, #T_e98e2_row0_col7, #T_e98e2_row0_col8, #T_e98e2_row1_col6 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_e98e2_row0_col6, #T_e98e2_row1_col3, #T_e98e2_row1_col4, #T_e98e2_row1_col5, #T_e98e2_row1_col7, #T_e98e2_row1_col8 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_e98e2_row1_col2 {
#   background-color: #89acfd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# </style>
# <table id="T_e98e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e98e2_level0_col0" class="col_heading level0 col0" >observation</th>
#       <th id="T_e98e2_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_e98e2_level0_col2" class="col_heading level0 col2" >bias</th>
#       <th id="T_e98e2_level0_col3" class="col_heading level0 col3" >rmse</th>
#       <th id="T_e98e2_level0_col4" class="col_heading level0 col4" >urmse</th>
#       <th id="T_e98e2_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_e98e2_level0_col6" class="col_heading level0 col6" >cc</th>
#       <th id="T_e98e2_level0_col7" class="col_heading level0 col7" >si</th>
#       <th id="T_e98e2_level0_col8" class="col_heading level0 col8" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e98e2_level0_row0" class="row_heading level0 row0" >SW_1</th>
#       <td id="T_e98e2_row0_col0" class="data row0 col0" >HKNA</td>
#       <td id="T_e98e2_row0_col1" class="data row0 col1" >386</td>
#       <td id="T_e98e2_row0_col2" class="data row0 col2" >-0.194</td>
#       <td id="T_e98e2_row0_col3" class="data row0 col3" >0.352</td>
#       <td id="T_e98e2_row0_col4" class="data row0 col4" >0.293</td>
#       <td id="T_e98e2_row0_col5" class="data row0 col5" >0.252</td>
#       <td id="T_e98e2_row0_col6" class="data row0 col6" >0.971</td>
#       <td id="T_e98e2_row0_col7" class="data row0 col7" >0.094</td>
#       <td id="T_e98e2_row0_col8" class="data row0 col8" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_e98e2_level0_row1" class="row_heading level0 row1" >SW_2</th>
#       <td id="T_e98e2_row1_col0" class="data row1 col0" >HKNA</td>
#       <td id="T_e98e2_row1_col1" class="data row1 col1" >386</td>
#       <td id="T_e98e2_row1_col2" class="data row1 col2" >-0.100</td>
#       <td id="T_e98e2_row1_col3" class="data row1 col3" >0.293</td>
#       <td id="T_e98e2_row1_col4" class="data row1 col4" >0.275</td>
#       <td id="T_e98e2_row1_col5" class="data row1 col5" >0.214</td>
#       <td id="T_e98e2_row1_col6" class="data row1 col6" >0.971</td>
#       <td id="T_e98e2_row1_col7" class="data row1 col7" >0.089</td>
#       <td id="T_e98e2_row1_col8" class="data row1 col8" >0.934</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.sel('rmse>0.25').style()
# Out:
# <style type="text/css">
# #T_6e2d6_row0_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6e2d6_row0_col2, #T_6e2d6_row1_col2 {
#   background-color: #fda872;
#   color: #000000;
# }
# #T_6e2d6_row0_col3 {
#   background-color: #fee8c9;
#   color: #000000;
# }
# #T_6e2d6_row0_col4 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_6e2d6_row0_col5, #T_6e2d6_row2_col5, #T_6e2d6_row3_col2, #T_6e2d6_row3_col3, #T_6e2d6_row3_col4, #T_6e2d6_row3_col6, #T_6e2d6_row3_col7 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_6e2d6_row0_col6 {
#   background-color: #feecd2;
#   color: #000000;
# }
# #T_6e2d6_row0_col7 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_6e2d6_row1_col1 {
#   background-color: #dcdddd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_6e2d6_row1_col3 {
#   background-color: #fa8656;
#   color: #f1f1f1;
# }
# #T_6e2d6_row1_col4 {
#   background-color: #f67a51;
#   color: #f1f1f1;
# }
# #T_6e2d6_row1_col5 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_6e2d6_row1_col6 {
#   background-color: #f16c4b;
#   color: #f1f1f1;
# }
# #T_6e2d6_row1_col7 {
#   background-color: #fdad77;
#   color: #000000;
# }
# #T_6e2d6_row2_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6e2d6_row2_col2, #T_6e2d6_row2_col3, #T_6e2d6_row2_col4, #T_6e2d6_row2_col6, #T_6e2d6_row2_col7, #T_6e2d6_row3_col5 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_6e2d6_row3_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_6e2d6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e2d6_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_6e2d6_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_6e2d6_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_6e2d6_level0_col3" class="col_heading level0 col3" >urmse</th>
#       <th id="T_6e2d6_level0_col4" class="col_heading level0 col4" >mae</th>
#       <th id="T_6e2d6_level0_col5" class="col_heading level0 col5" >cc</th>
#       <th id="T_6e2d6_level0_col6" class="col_heading level0 col6" >si</th>
#       <th id="T_6e2d6_level0_col7" class="col_heading level0 col7" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >observation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e2d6_level0_row0" class="row_heading level0 row0" rowspan="2">SW_1</th>
#       <th id="T_6e2d6_level1_row0" class="row_heading level1 row0" >HKNA</th>
#       <td id="T_6e2d6_row0_col0" class="data row0 col0" >386</td>
#       <td id="T_6e2d6_row0_col1" class="data row0 col1" >-0.194</td>
#       <td id="T_6e2d6_row0_col2" class="data row0 col2" >0.352</td>
#       <td id="T_6e2d6_row0_col3" class="data row0 col3" >0.293</td>
#       <td id="T_6e2d6_row0_col4" class="data row0 col4" >0.252</td>
#       <td id="T_6e2d6_row0_col5" class="data row0 col5" >0.971</td>
#       <td id="T_6e2d6_row0_col6" class="data row0 col6" >0.094</td>
#       <td id="T_6e2d6_row0_col7" class="data row0 col7" >0.905</td>
#     </tr>
#     <tr>
#       <th id="T_6e2d6_level1_row1" class="row_heading level1 row1" >c2</th>
#       <td id="T_6e2d6_row1_col0" class="data row1 col0" >113</td>
#       <td id="T_6e2d6_row1_col1" class="data row1 col1" >-0.001</td>
#       <td id="T_6e2d6_row1_col2" class="data row1 col2" >0.352</td>
#       <td id="T_6e2d6_row1_col3" class="data row1 col3" >0.352</td>
#       <td id="T_6e2d6_row1_col4" class="data row1 col4" >0.295</td>
#       <td id="T_6e2d6_row1_col5" class="data row1 col5" >0.974</td>
#       <td id="T_6e2d6_row1_col6" class="data row1 col6" >0.128</td>
#       <td id="T_6e2d6_row1_col7" class="data row1 col7" >0.900</td>
#     </tr>
#     <tr>
#       <th id="T_6e2d6_level0_row2" class="row_heading level0 row2" rowspan="2">SW_2</th>
#       <th id="T_6e2d6_level1_row2" class="row_heading level1 row2" >HKNA</th>
#       <td id="T_6e2d6_row2_col0" class="data row2 col0" >386</td>
#       <td id="T_6e2d6_row2_col1" class="data row2 col1" >-0.100</td>
#       <td id="T_6e2d6_row2_col2" class="data row2 col2" >0.293</td>
#       <td id="T_6e2d6_row2_col3" class="data row2 col3" >0.275</td>
#       <td id="T_6e2d6_row2_col4" class="data row2 col4" >0.214</td>
#       <td id="T_6e2d6_row2_col5" class="data row2 col5" >0.971</td>
#       <td id="T_6e2d6_row2_col6" class="data row2 col6" >0.089</td>
#       <td id="T_6e2d6_row2_col7" class="data row2 col7" >0.934</td>
#     </tr>
#     <tr>
#       <th id="T_6e2d6_level1_row3" class="row_heading level1 row3" >c2</th>
#       <td id="T_6e2d6_row3_col0" class="data row3 col0" >113</td>
#       <td id="T_6e2d6_row3_col1" class="data row3 col1" >0.081</td>
#       <td id="T_6e2d6_row3_col2" class="data row3 col2" >0.430</td>
#       <td id="T_6e2d6_row3_col3" class="data row3 col3" >0.422</td>
#       <td id="T_6e2d6_row3_col4" class="data row3 col4" >0.357</td>
#       <td id="T_6e2d6_row3_col5" class="data row3 col5" >0.974</td>
#       <td id="T_6e2d6_row3_col6" class="data row3 col6" >0.153</td>
#       <td id="T_6e2d6_row3_col7" class="data row3 col7" >0.850</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.sel('rmse>0.3', columns=['rmse','mae']).style()
# Out:
# <style type="text/css">
# #T_a8c51_row0_col0 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_a8c51_row0_col1, #T_a8c51_row1_col0 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_a8c51_row1_col1 {
#   background-color: #fdb07a;
#   color: #000000;
# }
# #T_a8c51_row2_col0, #T_a8c51_row2_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a8c51">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8c51_level0_col0" class="col_heading level0 col0" >rmse</th>
#       <th id="T_a8c51_level0_col1" class="col_heading level0 col1" >mae</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >observation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8c51_level0_row0" class="row_heading level0 row0" rowspan="2">SW_1</th>
#       <th id="T_a8c51_level1_row0" class="row_heading level1 row0" >HKNA</th>
#       <td id="T_a8c51_row0_col0" class="data row0 col0" >0.352</td>
#       <td id="T_a8c51_row0_col1" class="data row0 col1" >0.252</td>
#     </tr>
#     <tr>
#       <th id="T_a8c51_level1_row1" class="row_heading level1 row1" >c2</th>
#       <td id="T_a8c51_row1_col0" class="data row1 col0" >0.352</td>
#       <td id="T_a8c51_row1_col1" class="data row1 col1" >0.295</td>
#     </tr>
#     <tr>
#       <th id="T_a8c51_level0_row2" class="row_heading level0 row2" >SW_2</th>
#       <th id="T_a8c51_level1_row2" class="row_heading level1 row2" >c2</th>
#       <td id="T_a8c51_row2_col0" class="data row2 col0" >0.430</td>
#       <td id="T_a8c51_row2_col1" class="data row2 col1" >0.357</td>
#     </tr>
#   </tbody>
# </table>
