# %% [markdown]
# # Built-in datasets for demonstration purposes
#
# * Oresund water levels
# * Vistula river discharge

# %%
import modelskill as ms

# %% [markdown]
# ## Oresund water level
#
# Compare tide gauges to MIKE 21 HD results for the Oresund strait.

# %%
cc = ms.data.oresund()
cc
# Out:
# <ComparerCollection>
# Comparers:
# 0: Drogden - Surface Elevation [meter]
# 1: Barseback - Surface Elevation [meter]
# 2: Helsingborg - Surface Elevation [meter]
# 3: Kobenhavn - Surface Elevation [meter]
# 4: Koege - Surface Elevation [meter]
# 5: MalmoHamn - Surface Elevation [meter]
# 6: Skanor - Surface Elevation [meter]
# 7: Vedbaek - Surface Elevation [meter]

# %%
for cmp in cc:
    cmp.plot.timeseries()

# %% [markdown]
# ## Vistula river discharge
#
# Compare river discharge to DHI's Global Hydrological Model (GHM) for the Vistula river in Poland.

# %%
cc = ms.data.vistula()
cc
# Out:
# <ComparerCollection>
# Comparers:
# 0: VISTULA (TCZEW) - Discharge [m3/s]
# 1: PISA (PTAKI) - Discharge [m3/s]
# 2: NAREW (SURAZ) - Discharge [m3/s]
# 3: LIWIEC (LOCHOW) - Discharge [m3/s]
# 4: KRZNA (MALOWA GORA) - Discharge [m3/s]
# 5: PILICA (PRZEDBORZ) - Discharge [m3/s]
# 6: WIEPRZ (LUBARTOW) - Discharge [m3/s]
# 7: WIEPRZ (KRASNYSTAW) - Discharge [m3/s]
# 8: KAMIENNA (KUNOW) - Discharge [m3/s]
# 9: VISTULA (SANDOMIERZ) - Discharge [m3/s]
# 10: VISTULA (SZCZUCIN) - Discharge [m3/s]
# 11: DUNAJEC (NOWY SACZ) - Discharge [m3/s]
# 12: POPRAD (CHMELNICA) - Discharge [m3/s]
# 13: WISLOK (TRYNCZA) - Discharge [m3/s]

# %%
for cmp in cc:
    cmp.plot.timeseries()
