# %% [markdown]
# # Data-wrangling for forecasting
#
# This notebook provides a reference to write forecasting results in a format that can be incorporated into a workflow with modelskill.

# %%
import pandas as pd
import modelskill as ms

# %%
def path_to_file(filename):
    return f"../tests/testdata/forecast_skill/{filename}"

def melt_df_by_date(df, name):
    return pd.melt(df.reset_index(), id_vars=["date"], var_name="lead_time", value_name=name)


def wide_to_long_representation(forecasts):
    def get_horizon_series(row):
        new_index = (pd.to_datetime(row.name) - pd.to_datetime(row.index)).days
        return pd.Series(row.values, index=new_index)

    predictions_by_horizon = forecasts.T.apply(
        get_horizon_series, axis=1
    ).dropna(axis=1, how="all")
    predictions_by_horizon.index.name = "date"

    return predictions_by_horizon

# %% [markdown]
# Let´s assume we are developing a model to forecast the next 7 days of a variable _X_. There are multiple strategies to store the results of such model; the following dataframe shows one arbitrary method. Every row in this dataframe represents a week of forecasted values made the date denoted by the row index. Each of these rows contains only 7 values accounting for the forecast for the next 7 days: Let´s call this the _wide representation_.
#
# It is important to remark that this strategy might only be reasonable when the dataset is small enough, since this dataframe is very sparse. Still, one can follow the same structure while using a different storage method, e.g., a folder tree with subfolders for every day, where every subfolder contains a file with the forecast values.

# %%
forecast_model_1 = pd.read_csv(path_to_file("forecast_model_1.csv"), parse_dates=True, index_col=0)
forecast_model_1.head(10).round(2)
# Out:
#             2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  \
# 2022-12-31    15521.82    14296.53    13821.23    13312.48    13241.17
# 2023-01-01         NaN    13195.95    13037.03    12753.71    12843.03
# 2023-01-02         NaN         NaN    13207.27    12875.01    12929.46
# 2023-01-03         NaN         NaN         NaN    13342.34    13262.45
# 2023-01-04         NaN         NaN         NaN         NaN    13998.87
# 2023-01-05         NaN         NaN         NaN         NaN         NaN
# 2023-01-06         NaN         NaN         NaN         NaN         NaN
# 2023-01-07         NaN         NaN         NaN         NaN         NaN
# 2023-01-08         NaN         NaN         NaN         NaN         NaN
# 2023-01-09         NaN         NaN         NaN         NaN         NaN
#
#             2023-01-06  2023-01-07  2023-01-08  2023-01-09  2023-01-10  ...  \
# 2022-12-31    12847.62    13003.76         NaN         NaN         NaN  ...
# 2023-01-01    12563.93    12801.62    13731.58         NaN         NaN  ...
# 2023-01-02    12625.52    12845.50    13762.85    13145.25         NaN  ...
# 2023-01-03    12862.78    13014.56    13883.31    13231.08    13000.59  ...
# 2023-01-04    13387.50    13388.44    14149.71    13420.90    13135.85  ...
# 2023-01-05    13267.53    13302.96    14088.80    13377.50    13104.92  ...
# 2023-01-06         NaN    13804.10    14445.89    13631.93    13286.21  ...
# 2023-01-07         NaN         NaN    14813.45    13893.84    13472.83  ...
# 2023-01-08         NaN         NaN         NaN    14173.23    13671.91  ...
# 2023-01-09         NaN         NaN         NaN         NaN    13939.92  ...
#
#             2024-01-12  2024-01-13  2024-01-14  2024-01-15  2024-01-16  \
# 2022-12-31         NaN         NaN         NaN         NaN         NaN
# 2023-01-01         NaN         NaN         NaN         NaN         NaN
# 2023-01-02         NaN         NaN         NaN         NaN         NaN
# 2023-01-03         NaN         NaN         NaN         NaN         NaN
# 2023-01-04         NaN         NaN         NaN         NaN         NaN
# 2023-01-05         NaN         NaN         NaN         NaN         NaN
# 2023-01-06         NaN         NaN         NaN         NaN         NaN
# 2023-01-07         NaN         NaN         NaN         NaN         NaN
# 2023-01-08         NaN         NaN         NaN         NaN         NaN
# 2023-01-09         NaN         NaN         NaN         NaN         NaN
#
#             2024-01-17  2024-01-18  2024-01-19  2024-01-20  2024-01-21
# 2022-12-31         NaN         NaN         NaN         NaN         NaN
# 2023-01-01         NaN         NaN         NaN         NaN         NaN
# 2023-01-02         NaN         NaN         NaN         NaN         NaN
# 2023-01-03         NaN         NaN         NaN         NaN         NaN
# 2023-01-04         NaN         NaN         NaN         NaN         NaN
# 2023-01-05         NaN         NaN         NaN         NaN         NaN
# 2023-01-06         NaN         NaN         NaN         NaN         NaN
# 2023-01-07         NaN         NaN         NaN         NaN         NaN
# 2023-01-08         NaN         NaN         NaN         NaN         NaN
# 2023-01-09         NaN         NaN         NaN         NaN         NaN
#
# [10 rows x 386 columns]

# %% [markdown]
# When evaluating forecasting results, it is interesting to compare the forecast results at different horizons. We can more efficiently write the previous dataframe such that it is sorted by how long in advance were we forecasting each value. We can call this the _horizon representation_.

# %%
results_model_1 = wide_to_long_representation(forecast_model_1).dropna()
results_model_1.head(10).round(2)
# Out:
#                    1         2         3         4         5         6  \
# date
# 2023-01-07  13804.10  13302.96  13388.44  13014.56  12845.50  12801.62
# 2023-01-08  14813.45  14445.89  14088.80  14149.71  13883.31  13762.85
# 2023-01-09  14173.23  13893.84  13631.93  13377.50  13420.90  13231.08
# 2023-01-10  13939.92  13671.91  13472.83  13286.21  13104.92  13135.85
# 2023-01-11  14669.68  13872.50  13681.53  13539.68  13406.71  13277.53
# 2023-01-12  13441.08  14314.18  13746.16  13610.09  13509.02  13414.27
# 2023-01-13  14470.25  13174.05  13796.16  13391.43  13294.47  13222.46
# 2023-01-14  13611.65  14044.00  13120.41  13563.69  13275.30  13206.22
# 2023-01-15  15539.59  14242.69  14550.75  13892.66  14208.51  14003.03
# 2023-01-16  14242.70  14503.05  13578.96  13798.46  13329.56  13554.61
#
#                    7
# date
# 2023-01-07  13003.76
# 2023-01-08  13731.58
# 2023-01-09  13145.25
# 2023-01-10  13000.59
# 2023-01-11  13299.57
# 2023-01-12  13322.23
# 2023-01-13  13154.95
# 2023-01-14  13154.91
# 2023-01-15  13953.80
# 2023-01-16  13408.19

# %% [markdown]
# Notice that, despite we are working with a univariate time series, we _need_ two dimensions to evaluate the forecast results. One dimension (the rows) marks the date at which we aim to forecast the value of _X_; this dimensions is sometimes called the _analysis time_.The other dimension (the columns) represents the _horizon_ of our forecast, i.e. how many days in advance are we forecasting _X_. The horizon of a forecast will often impact significantly the model results as it is normally easier to predict values that are close.
#
# In order to compare these results with results from a different model using __modelskill__, we need to write the _horizon representation_ in long format, so we can use the lead time as an auxiliary feature. We can call this, the _long representation_. Finally, we need to include the actual observations of _X_ during the analysis time to assess the performance of the model.

# %%
melted_results_model_1 = melt_df_by_date(results_model_1, name="model_1")
observations = pd.read_csv(path_to_file("observations.csv"), parse_dates=True)
melted_results_model_1 = pd.merge(left=melted_results_model_1, right=observations, on="date")
melted_results_model_1.head().round(2)
# Out:
#          date lead_time   model_1  observation
# 0  2023-01-07         1  13804.10     14319.96
# 1  2023-01-08         1  14813.45     15205.57
# 2  2023-01-09         1  14173.23     14549.37
# 3  2023-01-10         1  13939.92     15058.72
# 4  2023-01-11         1  14669.68     13444.34

# %% [markdown]
# The following image shows an schematic of the previous workflow, where the labels _A_, _B_ denote the _wide representation_, the _horizon representation_. The label _C_ represents the _matched representation_, which is described in the following section. The green box to the right contains the actual observations of _X_ during the analysis time.
#
# (For the sake of brevity, the image shows an example where the horizon is 3 time-steps, instead of 7.)
#
#
# ![Data wrangling](../images/forecast_data_wrangling_wbackground.png)

# %% [markdown]
# ## Using modelskill
#
# After we have written the data in the _long format_, we can already call __modelskill__ to evaluate the performance of the model. As mentioned above, we are separating the forecast results by the lead time (or horizon). We see that all metrics get worse as the lead time increases, as expected.

# %%
cmp = ms.from_matched(melted_results_model_1, mod_items=["model_1"], aux_items=["lead_time"], obs_item="observation")
cmp.skill(by=["model", "lead_time"]).sort_index().round(2).style()
# Out:
# <style type="text/css">
# #T_1731b_row0_col2 {
#   background-color: #adc9fd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_1731b_row0_col3, #T_1731b_row0_col4, #T_1731b_row0_col5, #T_1731b_row0_col6, #T_1731b_row0_col7, #T_1731b_row0_col8 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_1731b_row1_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1731b_row1_col3 {
#   background-color: #fdd29c;
#   color: #000000;
# }
# #T_1731b_row1_col4, #T_1731b_row1_col5 {
#   background-color: #fdd49e;
#   color: #000000;
# }
# #T_1731b_row1_col6 {
#   background-color: #fedfb4;
#   color: #000000;
# }
# #T_1731b_row1_col7 {
#   background-color: #fdd49f;
#   color: #000000;
# }
# #T_1731b_row1_col8 {
#   background-color: #fddaab;
#   color: #000000;
# }
# #T_1731b_row2_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1731b_row2_col3 {
#   background-color: #f98556;
#   color: #f1f1f1;
# }
# #T_1731b_row2_col4 {
#   background-color: #fa8656;
#   color: #f1f1f1;
# }
# #T_1731b_row2_col5 {
#   background-color: #fc8e5a;
#   color: #f1f1f1;
# }
# #T_1731b_row2_col6 {
#   background-color: #fca26d;
#   color: #000000;
# }
# #T_1731b_row2_col7 {
#   background-color: #fc8c59;
#   color: #f1f1f1;
# }
# #T_1731b_row2_col8 {
#   background-color: #fc9b66;
#   color: #000000;
# }
# #T_1731b_row3_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1731b_row3_col3, #T_1731b_row3_col4 {
#   background-color: #dc3c28;
#   color: #f1f1f1;
# }
# #T_1731b_row3_col5 {
#   background-color: #df432d;
#   color: #f1f1f1;
# }
# #T_1731b_row3_col6 {
#   background-color: #e7533a;
#   color: #f1f1f1;
# }
# #T_1731b_row3_col7 {
#   background-color: #d62f1e;
#   color: #f1f1f1;
# }
# #T_1731b_row3_col8 {
#   background-color: #e9583e;
#   color: #f1f1f1;
# }
# #T_1731b_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1731b_row4_col3, #T_1731b_row4_col4 {
#   background-color: #bb0b07;
#   color: #f1f1f1;
# }
# #T_1731b_row4_col5 {
#   background-color: #bc0c08;
#   color: #f1f1f1;
# }
# #T_1731b_row4_col6 {
#   background-color: #c4170f;
#   color: #f1f1f1;
# }
# #T_1731b_row4_col7, #T_1731b_row5_col7, #T_1731b_row6_col3, #T_1731b_row6_col4, #T_1731b_row6_col5, #T_1731b_row6_col6, #T_1731b_row6_col7, #T_1731b_row6_col8 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_1731b_row4_col8 {
#   background-color: #c61a11;
#   color: #f1f1f1;
# }
# #T_1731b_row5_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1731b_row5_col3, #T_1731b_row5_col4 {
#   background-color: #990000;
#   color: #f1f1f1;
# }
# #T_1731b_row5_col5, #T_1731b_row5_col6 {
#   background-color: #9c0000;
#   color: #f1f1f1;
# }
# #T_1731b_row5_col8 {
#   background-color: #9e0000;
#   color: #f1f1f1;
# }
# #T_1731b_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1731b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1731b_level0_col0" class="col_heading level0 col0" >observation</th>
#       <th id="T_1731b_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_1731b_level0_col2" class="col_heading level0 col2" >bias</th>
#       <th id="T_1731b_level0_col3" class="col_heading level0 col3" >rmse</th>
#       <th id="T_1731b_level0_col4" class="col_heading level0 col4" >urmse</th>
#       <th id="T_1731b_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_1731b_level0_col6" class="col_heading level0 col6" >cc</th>
#       <th id="T_1731b_level0_col7" class="col_heading level0 col7" >si</th>
#       <th id="T_1731b_level0_col8" class="col_heading level0 col8" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >lead_time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1731b_level0_row0" class="row_heading level0 row0" rowspan="7">model_1</th>
#       <th id="T_1731b_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_1731b_row0_col0" class="data row0 col0" >observation</td>
#       <td id="T_1731b_row0_col1" class="data row0 col1" >374</td>
#       <td id="T_1731b_row0_col2" class="data row0 col2" >-172.710</td>
#       <td id="T_1731b_row0_col3" class="data row0 col3" >811.960</td>
#       <td id="T_1731b_row0_col4" class="data row0 col4" >793.380</td>
#       <td id="T_1731b_row0_col5" class="data row0 col5" >635.330</td>
#       <td id="T_1731b_row0_col6" class="data row0 col6" >0.900</td>
#       <td id="T_1731b_row0_col7" class="data row0 col7" >0.050</td>
#       <td id="T_1731b_row0_col8" class="data row0 col8" >0.800</td>
#     </tr>
#     <tr>
#       <th id="T_1731b_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_1731b_row1_col0" class="data row1 col0" >observation</td>
#       <td id="T_1731b_row1_col1" class="data row1 col1" >374</td>
#       <td id="T_1731b_row1_col2" class="data row1 col2" >-296.600</td>
#       <td id="T_1731b_row1_col3" class="data row1 col3" >996.070</td>
#       <td id="T_1731b_row1_col4" class="data row1 col4" >950.890</td>
#       <td id="T_1731b_row1_col5" class="data row1 col5" >794.870</td>
#       <td id="T_1731b_row1_col6" class="data row1 col6" >0.850</td>
#       <td id="T_1731b_row1_col7" class="data row1 col7" >0.060</td>
#       <td id="T_1731b_row1_col8" class="data row1 col8" >0.690</td>
#     </tr>
#     <tr>
#       <th id="T_1731b_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_1731b_row2_col0" class="data row2 col0" >observation</td>
#       <td id="T_1731b_row2_col1" class="data row2 col1" >374</td>
#       <td id="T_1731b_row2_col2" class="data row2 col2" >-384.350</td>
#       <td id="T_1731b_row2_col3" class="data row2 col3" >1184.790</td>
#       <td id="T_1731b_row2_col4" class="data row2 col4" >1120.720</td>
#       <td id="T_1731b_row2_col5" class="data row2 col5" >950.580</td>
#       <td id="T_1731b_row2_col6" class="data row2 col6" >0.780</td>
#       <td id="T_1731b_row2_col7" class="data row2 col7" >0.070</td>
#       <td id="T_1731b_row2_col8" class="data row2 col8" >0.560</td>
#     </tr>
#     <tr>
#       <th id="T_1731b_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_1731b_row3_col0" class="data row3 col0" >observation</td>
#       <td id="T_1731b_row3_col1" class="data row3 col1" >374</td>
#       <td id="T_1731b_row3_col2" class="data row3 col2" >-446.930</td>
#       <td id="T_1731b_row3_col3" class="data row3 col3" >1323.600</td>
#       <td id="T_1731b_row3_col4" class="data row3 col4" >1245.860</td>
#       <td id="T_1731b_row3_col5" class="data row3 col5" >1080.360</td>
#       <td id="T_1731b_row3_col6" class="data row3 col6" >0.720</td>
#       <td id="T_1731b_row3_col7" class="data row3 col7" >0.080</td>
#       <td id="T_1731b_row3_col8" class="data row3 col8" >0.460</td>
#     </tr>
#     <tr>
#       <th id="T_1731b_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_1731b_row4_col0" class="data row4 col0" >observation</td>
#       <td id="T_1731b_row4_col1" class="data row4 col1" >374</td>
#       <td id="T_1731b_row4_col2" class="data row4 col2" >-491.980</td>
#       <td id="T_1731b_row4_col3" class="data row4 col3" >1412.620</td>
#       <td id="T_1731b_row4_col4" class="data row4 col4" >1324.180</td>
#       <td id="T_1731b_row4_col5" class="data row4 col5" >1166.210</td>
#       <td id="T_1731b_row4_col6" class="data row4 col6" >0.680</td>
#       <td id="T_1731b_row4_col7" class="data row4 col7" >0.090</td>
#       <td id="T_1731b_row4_col8" class="data row4 col8" >0.380</td>
#     </tr>
#     <tr>
#       <th id="T_1731b_level1_row5" class="row_heading level1 row5" >6</th>
#       <td id="T_1731b_row5_col0" class="data row5 col0" >observation</td>
#       <td id="T_1731b_row5_col1" class=

# %% [markdown]
# ### Comparing two models
#
# Typically we will be interested in comparing different model candidates. In order to do that, we need to load the results from a different model and combine the results of the two models into a single _dataframe_ object.

# %%
forecast_model_2 = pd.read_csv(path_to_file("forecast_model_2.csv"), parse_dates=True, index_col=0)
results_model_2 = wide_to_long_representation(forecast_model_2).dropna()
melted_results_model_2 = melt_df_by_date(results_model_2, name="model_2")
melted_results_model_2 = pd.merge(left=melted_results_model_2, right=observations, on="date")

matched_model_results = melted_results_model_1.merge(
    melted_results_model_2,
    how="inner",
    on=["date","lead_time", "observation"]
    ).sort_values(
        by=["date", "lead_time"]
        ).set_index(
            "date"
            )

matched_model_results = matched_model_results.reindex(
                sorted(matched_model_results.columns),
                axis=1
                )

# We save the results as well for later use
matched_model_results.to_csv(path_to_file("matched_model_results.csv"))
matched_model_results.head().round(2)
# Out:
#            lead_time   model_1   model_2  observation
# date
# 2023-01-07         1  13804.10  12663.04     14319.96
# 2023-01-07         2  13302.96  12898.16     14319.96
# 2023-01-07         3  13388.44  13505.24     14319.96
# 2023-01-07         4  13014.56  13444.72     14319.96
# 2023-01-07         5  12845.50  13086.09     14319.96

# %% [markdown]
# Let's call this format, the _matched representation_, as previously introduced.
#
# With the previous dataframe object, it we can easily compare the performance of our two candidates.

# %%
cmp = ms.from_matched(matched_model_results, mod_items=["model_1", "model_2"], aux_items=["lead_time"], obs_item="observation")
cmp.skill(by=["model", "lead_time"]).sort_index().round(2).style()
# Out:
# <style type="text/css">
# #T_b8f05_row0_col2 {
#   background-color: #cad8ef;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_b8f05_row0_col3, #T_b8f05_row0_col4, #T_b8f05_row0_col5, #T_b8f05_row0_col6, #T_b8f05_row0_col7, #T_b8f05_row0_col8 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_b8f05_row1_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b8f05_row1_col3 {
#   background-color: #fee5c1;
#   color: #000000;
# }
# #T_b8f05_row1_col4 {
#   background-color: #fee0b7;
#   color: #000000;
# }
# #T_b8f05_row1_col5 {
#   background-color: #fedfb5;
#   color: #000000;
# }
# #T_b8f05_row1_col6, #T_b8f05_row1_col8 {
#   background-color: #feecd1;
#   color: #000000;
# }
# #T_b8f05_row1_col7 {
#   background-color: #fee2bb;
#   color: #000000;
# }
# #T_b8f05_row2_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b8f05_row2_col3 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_b8f05_row2_col4 {
#   background-color: #fdbc85;
#   color: #000000;
# }
# #T_b8f05_row2_col5 {
#   background-color: #fdbe87;
#   color: #000000;
# }
# #T_b8f05_row2_col6 {
#   background-color: #fdd8a7;
#   color: #000000;
# }
# #T_b8f05_row2_col7 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_b8f05_row2_col8 {
#   background-color: #fddaab;
#   color: #000000;
# }
# #T_b8f05_row3_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b8f05_row3_col3 {
#   background-color: #fdaf79;
#   color: #000000;
# }
# #T_b8f05_row3_col4, #T_b8f05_row6_col6 {
#   background-color: #fb8a58;
#   color: #f1f1f1;
# }
# #T_b8f05_row3_col5 {
#   background-color: #fb8b58;
#   color: #f1f1f1;
# }
# #T_b8f05_row3_col6 {
#   background-color: #fdc38c;
#   color: #000000;
# }
# #T_b8f05_row3_col7 {
#   background-color: #fc8c59;
#   color: #f1f1f1;
# }
# #T_b8f05_row3_col8 {
#   background-color: #fdca93;
#   color: #000000;
# }
# #T_b8f05_row4_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b8f05_row4_col3 {
#   background-color: #fc9560;
#   color: #000000;
# }
# #T_b8f05_row4_col4 {
#   background-color: #f26d4b;
#   color: #f1f1f1;
# }
# #T_b8f05_row4_col5 {
#   background-color: #f16c4b;
#   color: #f1f1f1;
# }
# #T_b8f05_row4_col6 {
#   background-color: #fdac76;
#   color: #000000;
# }
# #T_b8f05_row4_col7, #T_b8f05_row5_col7, #T_b8f05_row6_col7 {
#   background-color: #e7533a;
#   color: #f1f1f1;
# }
# #T_b8f05_row4_col8 {
#   background-color: #fdbb85;
#   color: #000000;
# }
# #T_b8f05_row5_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b8f05_row5_col3 {
#   background-color: #f98455;
#   color: #f1f1f1;
# }
# #T_b8f05_row5_col4 {
#   background-color: #e8553c;
#   color: #f1f1f1;
# }
# #T_b8f05_row5_col5 {
#   background-color: #e65239;
#   color: #f1f1f1;
# }
# #T_b8f05_row5_col6 {
#   background-color: #fc9863;
#   color: #000000;
# }
# #T_b8f05_row5_col8 {
#   background-color: #fda973;
#   color: #000000;
# }
# #T_b8f05_row6_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b8f05_row6_col3 {
#   background-color: #f57850;
#   color: #f1f1f1;
# }
# #T_b8f05_row6_col4, #T_b8f05_row9_col5 {
#   background-color: #df412c;
#   color: #f1f1f1;
# }
# #T_b8f05_row6_col5 {
#   background-color: #dc3c28;
#   color: #f1f1f1;
# }
# #T_b8f05_row6_col8 {
#   background-color: #fc9c67;
#   color: #000000;
# }
# #T_b8f05_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b8f05_row7_col3 {
#   background-color: #8f0000;
#   color: #f1f1f1;
# }
# #T_b8f05_row7_col4 {
#   background-color: #b40201;
#   color: #f1f1f1;
# }
# #T_b8f05_row7_col5, #T_b8f05_row10_col7, #T_b8f05_row11_col3, #T_b8f05_row11_col5, #T_b8f05_row11_col7, #T_b8f05_row11_col8, #T_b8f05_row12_col7, #T_b8f05_row13_col4, #T_b8f05_row13_col6, #T_b8f05_row13_col7 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_b8f05_row7_col6 {
#   background-color: #d52d1d;
#   color: #f1f1f1;
# }
# #T_b8f05_row7_col7, #T_b8f05_row8_col7, #T_b8f05_row9_col7 {
#   background-color: #be0f0a;
#   color: #f1f1f1;
# }
# #T_b8f05_row7_col8 {
#   background-color: #940000;
#   color: #f1f1f1;
# }
# #T_b8f05_row8_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b8f05_row8_col3 {
#   background-color: #a00000;
#   color: #f1f1f1;
# }
# #T_b8f05_row8_col4 {
#   background-color: #b20000;
#   color: #f1f1f1;
# }
# #T_b8f05_row8_col5 {
#   background-color: #970000;
#   color: #f1f1f1;
# }
# #T_b8f05_row8_col6 {
#   background-color: #cf2618;
#   color: #f1f1f1;
# }
# #T_b8f05_row8_col8 {
#   background-color: #ae0000;
#   color: #f1f1f1;
# }
# #T_b8f05_row9_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b8f05_row9_col3 {
#   background-color: #e44d35;
#   color: #f1f1f1;
# }
# #T_b8f05_row9_col4 {
#   background-color: #a80000;
#   color: #f1f1f1;
# }
# #T_b8f05_row9_col6, #T_b8f05_row12_col3 {
#   background-color: #c51810;
#   color: #f1f1f1;
# }
# #T_b8f05_row9_col8 {
#   background-color: #f3724e;
#   color: #f1f1f1;
# }
# #T_b8f05_row10_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b8f05_row10_col3 {
#   background-color: #ca1e14;
#   color: #f1f1f1;
# }
# #T_b8f05_row10_col4 {
#   background-color: #910000;
#   color: #f1f1f1;
# }
# #T_b8f05_row10_col5 {
#   background-color: #cd2316;
#   color: #f1f1f1;
# }
# #T_b8f05_row10_col6, #T_b8f05_row11_col6 {
#   background-color: #a60000;
#   color: #f1f1f1;
# }
# #T_b8f05_row10_col8 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
# }
# #T_b8f05_row11_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b8f05_row11_col4 {
#   background-color: #930000;
#   color: #f1f1f1;
# }
# #T_b8f05_row12_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b8f05_row12_col4, #T_b8f05_row13_col3 {
#   background-color: #860000;
#   color: #f1f1f1;
# }
# #T_b8f05_row12_col5 {
#   background-color: #c91d13;
#   color: #f1f1f1;
# }
# #T_b8f05_row12_col6 {
#   background-color: #8e0000;
#   color: #f1f1f1;
# }
# #T_b8f05_row12_col8 {
#   background-color: #d83221;
#   color: #f1f1f1;
# }
# #T_b8f05_row13_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b8f05_row13_col5 {
#   background-color: #8a0000;
#   color: #f1f1f1;
# }
# #T_b8f05_row13_col8 {
#   background-color: #890000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b8f05">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8f05_level0_col0" class="col_heading level0 col0" >observation</th>
#       <th id="T_b8f05_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_b8f05_level0_col2" class="col_heading level0 col2" >bias</th>
#       <th id="T_b8f05_level0_col3" class="col_heading level0 col3" >rmse</th>
#       <th id="T_b8f05_level0_col4" class="col_heading level0 col4" >urmse</th>
#       <th id="T_b8f05_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_b8f05_level0_col6" class="col_heading level0 col6" >cc</th>
#       <th id="T_b8f05_level0_col7" class="col_heading level0 col7" >si</th>
#       <th id="T_b8f05_level0_col8" class="col_heading level0 col8" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >lead_time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8f05_level0_row0" class="row_heading level0 row0" rowspan="7">model_1</th>
#       <th id="T_b8f05_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_b8f05_row0_col0" class="data row0 col0" >observation</td>
#       <td id="T_b8f05_row0_col1" class="data row0 col1" >374</td>
#       <td id="T_b8f05_row0_col2" class="data row0 col2" >-172.710</td>
#       <td id="T_b8f05_row0_col3" class="data row0 col3" >811.960</td>
#       <td id="T_b8f05_row0_col4" class="data row0 col4" >793.380</td>
#       <td id="T_b8f05_row0_col5" class="data row0 col5" >635.330</td>
#       <td id="T_b8f05_row0_col6" class="data row0 col6" >0.900</td>
#       <td id="T_b8f05_row0_col7" class="data row0 col7" >0.050</td>
#       <td id="T_b8f05_row0_col8" class="data row0 c
