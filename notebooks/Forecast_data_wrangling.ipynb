# %% [markdown]
# # Data-wrangling for forecasting
#
# This notebook provides a reference to write forecasting results in a format that can be incorporated into a workflow with modelskill.

# %%
import pandas as pd
import modelskill as ms

# %%
def path_to_file(filename):
    return f"../tests/testdata/forecast_skill/{filename}"

def melt_df_by_date(df, name):
    return pd.melt(df.reset_index(), id_vars=["date"], var_name="lead_time", value_name=name)


def window_to_horizon_representation(forecasts):
    def get_horizon_series(row):
        new_index = (pd.to_datetime(row.name) - pd.to_datetime(row.index)).days
        return pd.Series(row.values, index=new_index)

    predictions_by_horizon = forecasts.T.apply(
        get_horizon_series, axis=1
    ).dropna(axis=1, how="all")
    predictions_by_horizon.index.name = "date"

    return predictions_by_horizon

# %% [markdown]
# Let´s assume we have a model to forecast the next 7 days of an arbitrary variable. In such case, we can arrange the results of such model as the following dataframe.
#
# Every row in this dataframe represents a week of forecasted values made the date denoted by the row index. Notice that every row contains only 7 values accounting for the next 7 days: Let´s call this the _window representation_.

# %%
forecast_model_1 = pd.read_csv(path_to_file("forecast_model_1.csv"), parse_dates=True, index_col=0)
forecast_model_1.head(10).round(2)
# Out:
#             2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  \
# 2022-12-31    15521.82    14296.53    13821.23    13312.48    13241.17
# 2023-01-01         NaN    13195.95    13037.03    12753.71    12843.03
# 2023-01-02         NaN         NaN    13207.27    12875.01    12929.46
# 2023-01-03         NaN         NaN         NaN    13342.34    13262.45
# 2023-01-04         NaN         NaN         NaN         NaN    13998.87
# 2023-01-05         NaN         NaN         NaN         NaN         NaN
# 2023-01-06         NaN         NaN         NaN         NaN         NaN
# 2023-01-07         NaN         NaN         NaN         NaN         NaN
# 2023-01-08         NaN         NaN         NaN         NaN         NaN
# 2023-01-09         NaN         NaN         NaN         NaN         NaN
#
#             2023-01-06  2023-01-07  2023-01-08  2023-01-09  2023-01-10  ...  \
# 2022-12-31    12847.62    13003.76         NaN         NaN         NaN  ...
# 2023-01-01    12563.93    12801.62    13731.58         NaN         NaN  ...
# 2023-01-02    12625.52    12845.50    13762.85    13145.25         NaN  ...
# 2023-01-03    12862.78    13014.56    13883.31    13231.08    13000.59  ...
# 2023-01-04    13387.50    13388.44    14149.71    13420.90    13135.85  ...
# 2023-01-05    13267.53    13302.96    14088.80    13377.50    13104.92  ...
# 2023-01-06         NaN    13804.10    14445.89    13631.93    13286.21  ...
# 2023-01-07         NaN         NaN    14813.45    13893.84    13472.83  ...
# 2023-01-08         NaN         NaN         NaN    14173.23    13671.91  ...
# 2023-01-09         NaN         NaN         NaN         NaN    13939.92  ...
#
#             2024-01-12  2024-01-13  2024-01-14  2024-01-15  2024-01-16  \
# 2022-12-31         NaN         NaN         NaN         NaN         NaN
# 2023-01-01         NaN         NaN         NaN         NaN         NaN
# 2023-01-02         NaN         NaN         NaN         NaN         NaN
# 2023-01-03         NaN         NaN         NaN         NaN         NaN
# 2023-01-04         NaN         NaN         NaN         NaN         NaN
# 2023-01-05         NaN         NaN         NaN         NaN         NaN
# 2023-01-06         NaN         NaN         NaN         NaN         NaN
# 2023-01-07         NaN         NaN         NaN         NaN         NaN
# 2023-01-08         NaN         NaN         NaN         NaN         NaN
# 2023-01-09         NaN         NaN         NaN         NaN         NaN
#
#             2024-01-17  2024-01-18  2024-01-19  2024-01-20  2024-01-21
# 2022-12-31         NaN         NaN         NaN         NaN         NaN
# 2023-01-01         NaN         NaN         NaN         NaN         NaN
# 2023-01-02         NaN         NaN         NaN         NaN         NaN
# 2023-01-03         NaN         NaN         NaN         NaN         NaN
# 2023-01-04         NaN         NaN         NaN         NaN         NaN
# 2023-01-05         NaN         NaN         NaN         NaN         NaN
# 2023-01-06         NaN         NaN         NaN         NaN         NaN
# 2023-01-07         NaN         NaN         NaN         NaN         NaN
# 2023-01-08         NaN         NaN         NaN         NaN         NaN
# 2023-01-09         NaN         NaN         NaN         NaN         NaN
#
# [10 rows x 386 columns]

# %% [markdown]
# When evaluating forecasting results, it is interesting to compare the forecast results at different horizons. We can more efficiently write the previous dataframe such that it is sorted by how long in advance were we forecasting each value. We can call this the _horizon representation_.

# %%
results_model_1 = window_to_horizon_representation(forecast_model_1).dropna()
results_model_1.head(10).round(2)
# Out:
#                    1         2         3         4         5         6  \
# date
# 2023-01-07  13804.10  13302.96  13388.44  13014.56  12845.50  12801.62
# 2023-01-08  14813.45  14445.89  14088.80  14149.71  13883.31  13762.85
# 2023-01-09  14173.23  13893.84  13631.93  13377.50  13420.90  13231.08
# 2023-01-10  13939.92  13671.91  13472.83  13286.21  13104.92  13135.85
# 2023-01-11  14669.68  13872.50  13681.53  13539.68  13406.71  13277.53
# 2023-01-12  13441.08  14314.18  13746.16  13610.09  13509.02  13414.27
# 2023-01-13  14470.25  13174.05  13796.16  13391.43  13294.47  13222.46
# 2023-01-14  13611.65  14044.00  13120.41  13563.69  13275.30  13206.22
# 2023-01-15  15539.59  14242.69  14550.75  13892.66  14208.51  14003.03
# 2023-01-16  14242.70  14503.05  13578.96  13798.46  13329.56  13554.61
#
#                    7
# date
# 2023-01-07  13003.76
# 2023-01-08  13731.58
# 2023-01-09  13145.25
# 2023-01-10  13000.59
# 2023-01-11  13299.57
# 2023-01-12  13322.23
# 2023-01-13  13154.95
# 2023-01-14  13154.91
# 2023-01-15  13953.80
# 2023-01-16  13408.19

# %% [markdown]
# Finally, in order to compare these results with results from a different model using __modelskill__, we need to write the _horizon representation_ in long format as follows. Notice that the we have kept a `lead_time` column, which will be used later.

# %%
melted_results_model_1 = melt_df_by_date(results_model_1, name="model_1")
observations = pd.read_csv(path_to_file("observations.csv"), parse_dates=True)
melted_results_model_1 = pd.merge(left=melted_results_model_1, right=observations, on="date")
melted_results_model_1.head().round(2)
# Out:
#          date lead_time   model_1  observation
# 0  2023-01-07         1  13804.10     14319.96
# 1  2023-01-08         1  14813.45     15205.57
# 2  2023-01-09         1  14173.23     14549.37
# 3  2023-01-10         1  13939.92     15058.72
# 4  2023-01-11         1  14669.68     13444.34

# %% [markdown]
# Now, let´s load results computed with a different model and repeat the steps above.

# %%
forecast_model_2 = pd.read_csv(path_to_file("forecast_model_2.csv"), parse_dates=True, index_col=0)
results_model_2 = window_to_horizon_representation(forecast_model_2).dropna()
melted_results_model_2 = melt_df_by_date(results_model_2, name="model_2")
melted_results_model_2 = pd.merge(left=melted_results_model_2, right=observations, on="date")

# %% [markdown]
# Finally, we need to combine the results of the two models into a single _dataframe_ object. Let's call this format, the _matched representation_.

# %%
matched_model_results = melted_results_model_1.merge(
    melted_results_model_2,
    how="inner",
    on=["date","lead_time", "observation"]
    ).sort_values(
        by=["date", "lead_time"]
        ).set_index(
            "date"
            )

matched_model_results = matched_model_results.reindex(
                sorted(matched_model_results.columns),
                axis=1
                )

# We save the results as well for later use
matched_model_results.to_csv(path_to_file("matched_model_results.csv"))
matched_model_results.head().round(2)
# Out:
#            lead_time   model_1   model_2  observation
# date
# 2023-01-23         1  14167.08  13198.01     14513.21
# 2023-01-23         2  13850.32  13096.03     14513.21
# 2023-01-23         3  13683.14  13844.50     14513.21
# 2023-01-23         4  13239.73  13528.56     14513.21
# 2023-01-23         5  13088.73  13009.16     14513.21

# %% [markdown]
# The following image shows an schematic representation of the previous workflow, where the labels, _A_, _B_ and _C_ denote the _window representation_, the _horizon representation_ and the _matched representation_ respectively. Notice that, for the sake of brevity, the image shows an example where the horizon is 3 time-steps, instead of 7.
#
# ![Data wrangling](../images/forecast_data_wrangling_wbackground.png)

# %% [markdown]
# ## Using modelskill
#
# Departing from the _matched representation_, it is straightforward to create a _Comparer_ object using __modelskill__. After introducing the results labelled by lead_time, we can easily compare the performance at different horizons.

# %%
cmp = ms.from_matched(matched_model_results, mod_items=["model_1", "model_2"], aux_items=["lead_time"], obs_item="observation")
cmp.skill(by=["model", "lead_time"]).sort_index().round(2).style()
# Out:
# <style type="text/css">
# #T_c224a_row0_col2 {
#   background-color: #adc9fd;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_c224a_row0_col3, #T_c224a_row0_col8 {
#   background-color: #fff6ea;
#   color: #000000;
# }
# #T_c224a_row0_col4 {
#   background-color: #fff0db;
#   color: #000000;
# }
# #T_c224a_row0_col5, #T_c224a_row0_col6, #T_c224a_row0_col7, #T_c224a_row1_col3, #T_c224a_row1_col7, #T_c224a_row1_col8, #T_c224a_row2_col4, #T_c224a_row2_col6, #T_c224a_row2_col7 {
#   background-color: #fff7ec;
#   color: #000000;
#   text-decoration: underline;
#   font-style: italic;
#   font-weight: bold;
# }
# #T_c224a_row1_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_c224a_row1_col4 {
#   background-color: #fff4e5;
#   color: #000000;
# }
# #T_c224a_row1_col5, #T_c224a_row2_col3 {
#   background-color: #feedd3;
#   color: #000000;
# }
# #T_c224a_row1_col6 {
#   background-color: #fff4e4;
#   color: #000000;
# }
# #T_c224a_row2_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c224a_row2_col5 {
#   background-color: #fee2bc;
#   color: #000000;
# }
# #T_c224a_row2_col8 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_c224a_row3_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_c224a_row3_col3, #T_c224a_row4_col3 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_c224a_row3_col4 {
#   background-color: #fdd8a6;
#   color: #000000;
# }
# #T_c224a_row3_col5, #T_c224a_row4_col5 {
#   background-color: #fdb67f;
#   color: #000000;
# }
# #T_c224a_row3_col6, #T_c224a_row5_col6 {
#   background-color: #fee9cb;
#   color: #000000;
# }
# #T_c224a_row3_col7, #T_c224a_row4_col7, #T_c224a_row5_col7, #T_c224a_row6_col7 {
#   background-color: #fdd49f;
#   color: #000000;
# }
# #T_c224a_row3_col8, #T_c224a_row4_col8, #T_c224a_row6_col4 {
#   background-color: #fddeb3;
#   color: #000000;
# }
# #T_c224a_row4_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c224a_row4_col4 {
#   background-color: #fdddb0;
#   color: #000000;
# }
# #T_c224a_row4_col6, #T_c224a_row6_col6 {
#   background-color: #fee5c3;
#   color: #000000;
# }
# #T_c224a_row5_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c224a_row5_col3 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_c224a_row5_col4 {
#   background-color: #fedfb4;
#   color: #000000;
# }
# #T_c224a_row5_col5 {
#   background-color: #fda973;
#   color: #000000;
# }
# #T_c224a_row5_col8 {
#   background-color: #fdd9aa;
#   color: #000000;
# }
# #T_c224a_row6_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c224a_row6_col3 {
#   background-color: #fdc690;
#   color: #000000;
# }
# #T_c224a_row6_col5 {
#   background-color: #fda56f;
#   color: #000000;
# }
# #T_c224a_row6_col8 {
#   background-color: #fdd6a2;
#   color: #000000;
# }
# #T_c224a_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c224a_row7_col3 {
#   background-color: #9b0000;
#   color: #f1f1f1;
# }
# #T_c224a_row7_col4 {
#   background-color: #f26e4c;
#   color: #f1f1f1;
# }
# #T_c224a_row7_col5 {
#   background-color: #890000;
#   color: #f1f1f1;
# }
# #T_c224a_row7_col6 {
#   background-color: #fc9c67;
#   color: #000000;
# }
# #T_c224a_row7_col7, #T_c224a_row10_col7 {
#   background-color: #d62f1e;
#   color: #f1f1f1;
# }
# #T_c224a_row7_col8 {
#   background-color: #a80000;
#   color: #f1f1f1;
# }
# #T_c224a_row8_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c224a_row8_col3 {
#   background-color: #d2291a;
#   color: #f1f1f1;
# }
# #T_c224a_row8_col4 {
#   background-color: #fdbf88;
#   color: #000000;
# }
# #T_c224a_row8_col5 {
#   background-color: #bc0c08;
#   color: #f1f1f1;
# }
# #T_c224a_row8_col6 {
#   background-color: #fddcaf;
#   color: #000000;
# }
# #T_c224a_row8_col7, #T_c224a_row9_col7 {
#   background-color: #fc8c59;
#   color: #f1f1f1;
# }
# #T_c224a_row8_col8 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_c224a_row9_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c224a_row9_col3, #T_c224a_row9_col6 {
#   background-color: #fdbb85;
#   color: #000000;
# }
# #T_c224a_row9_col4 {
#   background-color: #fa8656;
#   color: #f1f1f1;
# }
# #T_c224a_row9_col5 {
#   background-color: #fdd39d;
#   color: #000000;
# }
# #T_c224a_row9_col8 {
#   background-color: #fdcc96;
#   color: #000000;
# }
# #T_c224a_row10_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c224a_row10_col3 {
#   background-color: #f4754f;
#   color: #f1f1f1;
# }
# #T_c224a_row10_col4 {
#   background-color: #ef6447;
#   color: #f1f1f1;
# }
# #T_c224a_row10_col5, #T_c224a_row10_col8 {
#   background-color: #fc925e;
#   color: #000000;
# }
# #T_c224a_row10_col6 {
#   background-color: #fda872;
#   color: #000000;
# }
# #T_c224a_row11_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c224a_row11_col3 {
#   background-color: #940000;
#   color: #f1f1f1;
# }
# #T_c224a_row11_col4 {
#   background-color: #c61a11;
#   color: #f1f1f1;
# }
# #T_c224a_row11_col5 {
#   background-color: #8e0000;
#   color: #f1f1f1;
# }
# #T_c224a_row11_col6 {
#   background-color: #de3f2b;
#   color: #f1f1f1;
# }
# #T_c224a_row11_col7, #T_c224a_row12_col7, #T_c224a_row13_col3, #T_c224a_row13_col4, #T_c224a_row13_col5, #T_c224a_row13_col6, #T_c224a_row13_col7, #T_c224a_row13_col8 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_c224a_row11_col8 {
#   background-color: #9e0000;
#   color: #f1f1f1;
# }
# #T_c224a_row12_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c224a_row12_col3 {
#   background-color: #da3724;
#   color: #f1f1f1;
# }
# #T_c224a_row12_col4 {
#   background-color: #960000;
#   color: #f1f1f1;
# }
# #T_c224a_row12_col5 {
#   background-color: #e9573d;
#   color: #f1f1f1;
# }
# #T_c224a_row12_col6 {
#   background-color: #a10000;
#   color: #f1f1f1;
# }
# #T_c224a_row12_col8 {
#   background-color: #e8553c;
#   color: #f1f1f1;
# }
# #T_c224a_row13_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c224a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c224a_level0_col0" class="col_heading level0 col0" >observation</th>
#       <th id="T_c224a_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_c224a_level0_col2" class="col_heading level0 col2" >bias</th>
#       <th id="T_c224a_level0_col3" class="col_heading level0 col3" >rmse</th>
#       <th id="T_c224a_level0_col4" class="col_heading level0 col4" >urmse</th>
#       <th id="T_c224a_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_c224a_level0_col6" class="col_heading level0 col6" >cc</th>
#       <th id="T_c224a_level0_col7" class="col_heading level0 col7" >si</th>
#       <th id="T_c224a_level0_col8" class="col_heading level0 col8" >r2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >lead_time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c224a_level0_row0" class="row_heading level0 row0" rowspan="7">model_1</th>
#       <th id="T_c224a_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_c224a_row0_col0" class="data row0 col0" >observation</td>
#       <td id="T_c224a_row0_col1" class="data row0 col1" >21</td>
#       <td id="T_c224a_row0_col2" class="data row0 col2" >-514.610</td>
#       <td id="T_c224a_row0_col3" class="data row0 col3" >987.500</td>
#       <td id="T_c224a_row0_col4" class="data row0 col4" >842.800</td>
#       <td id="T_c224a_row0_col5" class="data row0 col5" >780.730</td>
#       <td id="T_c224a_row0_col6" class="data row0 col6" >0.890</td>
#       <td id="T_c224a_row0_col7" class="data row0 col7" >0.050</td>
#       <td id="T_c224a_row0_col8" class="data row0 col8" >0.660</td>
#     </tr>
#     <tr>
#       <th id="T_c224a_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_c224a_row1_col0" class="data row1 col0" >observation</td>
#       <td id="T_c224a_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_c224a_row1_col2" class="data row1 c
